# %% [markdown]
# # Выборка и агрегация данных в MongoDB
#
# ###Цель домашней работы
#
# Закрепить на практике основные приемы работы с СУБД MongoDB, включая выборку, сортировку, объединение, агрегацию данных и передачу результатов выборки в программу на Python в целях аналитики и дальнейшей обработки.

# %% [markdown]
# ### Формулировка задания
#
# В этом задании вам предстоит выполнить несколько запросов к базе данных для получения выборок по условиям, а также воспользоваться фреймворком агрегации MongoDB для построения конвейера обработки данных.
#
# Максимальное количество баллов за выполнение домашней работы: 10.

# %% [markdown]
# ##Что нужно использовать в работе над заданием
#
# I. MongoDB:
#
# 1. Зарегистрируйтесь в сервисе MongoDB Atlas: https://www.mongodb.com/atlas/database.
# 1. Создайте кластер уровня M0 (это бесплатно).
# 1. Добавьте в кластер тестовую базу данных `sample_mflix`, используя опцию Load Sample Dataset.
#
# В качестве альтернативы вы можете установить MongoDB на свой локальный компьютер и импортировать необходимые датасеты в свою СУБД, загрузив их по ссылке: https://github.com/neelabalan/mongodb-sample-dataset/tree/main/sample_mflix. Для этого подключитесь к своему серверу через Compass, создайте новую БД, создайте для каждого датасета коллекцию и щелкните «Add data» → «Import JSON or CSV file».
#
# II. MongoDB Compass — в качестве вспомогательного инструмента для конструирования запросов и агрегаций.
#
# III. Python и библиотека pymongo. Работа ведется в Jupyter Notebook или Google Colaboratory. Рекомендуется использовать версию Python 3.12.

# %% [markdown]
# ##Ожидаемые результаты
#
# Результаты работы необходимо оформить в виде ноутбука Jupyter. Можно загрузить файл в LMS либо поделиться ссылкой на Google Colaboratory.

# %% [markdown]
# ##Место где нужно выполнить задание

# %%
#Начать выполнение задания тут

# %%
# !pip install pymongo

import pymongo

client = pymongo.MongoClient("mongodb+srv://olga_poletkina:Poletkol_1983@cluster0.daep2.mongodb.net/")
client.list_database_names()  # Вывести список БД для проверки подключения
# Out:
# Collecting pymongo
#   Downloading pymongo-4.11.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Downloading dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Downloading pymongo-4.11.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 25.7 MB/s eta 0:00:00
# Downloading dnspython-2.7.0-py3-none-any.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 20.8 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.7.0 pymongo-4.11.1
# ['my_database',
#  'my_db',
#  'sample_airbnb',
#  'sample_geospatial',
#  'sample_mflix',
#  'sample_restaurants',
#  'sample_weatherdata',
#  'admin',
#  'local']

# %% [markdown]
# ### Упражнение 1. Запросы на выборку

# %% [markdown]
# Цель этого упражнения — закрепить навык выполнения запросов на выборку. Все запросы выполняются на базе `sample_mflix` с данными о кинофильмах.

# %% [markdown]
# #### Задача 1.1 — **1 балл**

# %% [markdown]
# Выведите из коллекции `theaters` документы о кинотеатрах в городе Florence, штат KY.
#
# Для справки:
#
# * Обратите внимание на то, что информация об адресе кинотеатров хранится во вложенных документах. Для доступа к полям вложенных документов следует использовать точку: `родительский_документ.вложенный_документ.поле`.
# * В случае затруднений с написанием логического условия обращайтесь к сопоставлению синтаксиса SQL и Mongo: https://www.mongodb.com/docs/manual/reference/sql-comparison/.
# * Если вы предпочитаете сперва выполнять запросы в Compass, из этого приложения можно выгружать код готового запроса на Python (кнопка с символом `</>`).

# %%
# Ваш код здесь
db = client["sample_mflix"]
theaters_collection = db["theaters"]

query = {
    "location.address.city": "Florence",
    "location.address.state": "KY"
}

results = theaters_collection.find(query)

for theater in results:
    print(theater)
# Out:
# {'_id': ObjectId('59a47287cfa9a3a73e51e893'), 'theaterId': 161, 'location': {'address': {'street1': '100 Meijer Dr.', 'city': 'Florence', 'state': 'KY', 'zipcode': '41042'}, 'geo': {'type': 'Point', 'coordinates': [-84.636383, 39.014843]}}}
# {'_id': ObjectId('59a47287cfa9a3a73e51ea02'), 'theaterId': 2823, 'location': {'address': {'street1': '2823 Florence Mall', 'street2': '#2148', 'city': 'Florence', 'state': 'KY', 'zipcode': '41042'}, 'geo': {'type': 'Point', 'coordinates': [-84.6499595, 38.9967246]}}}

# %% [markdown]
# #### Задача 1.2 — **1 балл**

# %% [markdown]
# Сделав запрос к коллекции `comments`, выведите _один_ комментарий (значение поля `text`) пользователя по имени Doreah.

# %%
# Ваш код здесь
comments_collection = db["comments"]

query = {
    "name": "Doreah"
}

results = comments_collection.find(query)

results.next()["text"]
# Out:
# 'Porro explicabo cumque vitae sint quia quis. Consequuntur voluptatibus optio maxime ratione temporibus incidunt minus architecto.'

# %% [markdown]
# #### Задача 1.3 — **1 балл**

# %% [markdown]
# Сделав запрос к коллекции `movies`, выведите количество документов, в которых в качестве первого жанра фильма (поле `genres`) указано значение «Horror».
#
# Для справки:
#
# 1. Обратите внимание, что поле `genres` представляет собой массив (индексация массивов начинается с нуля).
# 1. При работе в MongoDB Shell для подсчета количества документов в курсоре можно использовать метод `count()`, однако он был удален в последних версиях библиотеки pymongo. В случае затруднений с использованием функций Mongo можно использовать для подсчета документов средства Python.

# %%
# Ваш код здесь
movies_collection = db["movies"]

query = {
    "genres.0": "Horror"
}

count = movies_collection.count_documents(query)

print(f"Количество фильмов, у которых первый жанр 'Horror': {count}")
# Out:
# Количество фильмов, у которых первый жанр 'Horror': 700

# %% [markdown]
# #### Задача 1.4 — **2 балла**

# %% [markdown]
# Выведите из коллекции `movies` документы о фильмах, которые в качестве первого жанра определены как «Film-Noir» либо «Horror» и были выпущены в период с 1940 по 1949 гг. (включительно).

# %%
# Ваш код здесь
query = {
    "genres.0": {"$in" : ["Film-Noir", "Horror"]},
    "year": {"$gte": 1940, "$lte": 1949}
}

results = movies_collection.find(query)

for movie in results:
    print(movie)
# Out:
# {'_id': ObjectId('573a1393f29313caabcdc814'), 'plot': "An American man marries a Serbian immigrant who fears that she will turn into the cat person of her homeland's fables if they are intimate together.", 'genres': ['Horror', 'Thriller'], 'runtime': 73, 'rated': 'APPROVED', 'cast': ['Simone Simon', 'Kent Smith', 'Tom Conway', 'Jane Randolph'], 'poster': 'https://m.media-amazon.com/images/M/MV5BNzI4YWY0NWQtNWI5YS00MGE4LWE4YTgtMzBmOWIwMzdiYTRiL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_SY1000_SX677_AL_.jpg', 'title': 'Cat People', 'fullplot': 'Irena Dubrovna, a beautiful and mysterious Serbian-born fashion artist living in New York City, falls in love with and marries average-Joe American Oliver Reed. Their marriage suffers though, as Irena believes that she suffers from an ancient curse- whenever emotionally aroused, she will turn into a panther and kill. Oliver thinks that is absurd and childish, so he sends her to psychiatrist Dr. Judd to cure her. Easier said than done...', 'languages': ['English', 'Czech', 'Serbian'], 'released': datetime.datetime(1942, 12, 25, 0, 0), 'directors': ['Jacques Tourneur'], 'writers': ['DeWitt Bodeen'], 'awards': {'wins': 1, 'nominations': 2, 'text': '1 win & 2 nominations.'}, 'lastupdated': '2015-08-21 00:53:54.453000000', 'year': 1942, 'imdb': {'rating': 7.4, 'votes': 11589, 'id': 34587}, 'countries': ['USA'], 'type': 'movie', 'tomatoes': {'viewer': {'rating': 3.6, 'numReviews': 7115}, 'critic': {'rating': 8.3, 'numReviews': 40, 'meter': 93}, 'lastUpdated': datetime.datetime(2015, 9, 15, 17, 3, 25), 'consensus': 'Influential noir director Jacques Tourneau infused this sexy, moody horror film with some sly commentary about the psychology and the taboos of desire.', 'rotten': 3, 'production': 'RKO Pictures', 'fresh': 37}, 'num_mflix_comments': 0}
# {'_id': ObjectId('573a1393f29313caabcdcd9d'), 'plot': 'A young Canadian nurse (Betsy) comes to the West Indies to care for Jessica, the wife of a plantation manager (Paul Holland). Jessica seems to be suffering from a kind of mental paralysis ...', 'genres': ['Horror'], 'runtime': 69, 'rated': 'APPROVED', 'cast': ['James Ellison', 'Frances Dee', 'Tom Conway', 'Edith Barrett'], 'num_mflix_comments': 1, 'poster': 'https://m.media-amazon.com/images/M/MV5BZjQzMzliN2YtYTVhNC00Zjc4LThjMmYtMTE0ZGUzMWNmYzJlXkEyXkFqcGdeQXVyMTYxNjkxOQ@@._V1_SY1000_SX677_AL_.jpg', 'title': 'I Walked with a Zombie', 'fullplot': 'A young Canadian nurse (Betsy) comes to the West Indies to care for Jessica, the wife of a plantation manager (Paul Holland). Jessica seems to be suffering from a kind of mental paralysis as a result of fever. When she falls in love with Paul, Betsy determines to cure Jessica even if she needs to use a voodoo ceremony, to give Paul what she thinks he wants.', 'languages': ['English'], 'released': datetime.datetime(1943, 4, 30, 0, 0), 'directors': ['Jacques Tourneur'], 'writers': ['Curt Siodmak (screenplay)', 'Ardel Wray (screenplay)', 'Inez Wallace (original story)'], 'awards': {'wins': 0, 'nominations': 2, 'text': '2 nominations.'}, 'lastupdated': '2015-08-16 00:16:16.823000000', 'year': 1943, 'imdb': {'rating': 7.3, 'votes': 6893, 'id': 36027}, 'countries': ['USA'], 'type': 'movie', 'tomatoes': {'viewer': {'rating': 3.6, 'numReviews': 4884, 'meter': 75}, 'dvd': datetime.datetime(2005, 10, 4, 0, 0), 'critic': {'rating': 8.1, 'numReviews': 26, 'meter': 92}, 'lastUpdated': datetime.datetime(2015, 8, 26, 18, 16, 16), 'consensus': "Evocative direction by Jacques Tourneur collides with the low-rent production values of exploitateer Val Lewton in I Walked with a Zombie, a sultry sleeper that's simultaneously smarmy, eloquent and fascinating.", 'rotten': 2, 'production': 'Warner Home Video', 'fresh': 24}}
# {'_id': ObjectId('573a1393f29313caabcdcdf5'), 'plot': 'A seemingly tame leopard used for a publicity stunt escapes and kills a young girl, spreading panic throughout a sleepy new Mexico town.', 'genres': ['Horror', 'Thriller'], 'runtime': 66, 'rated': 'APPROVED', 'cast': ["Dennis O'Keefe", 'Margo', 'Jean Brooks', 'Isabel Jewell'], 'num_mflix_comments': 0, 'poster': 'https://m.media-amazon.com/images/M/MV5BYmU4ZDI5NGMtYzM1OC00YTQ3LWI1NTEtNGM0Mzc0ZDA5NzI4XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SY1000_SX677_AL_.jpg', 'title': 'The Leopard Man', 'fullplot': 'At the encouragement of her manager, a nightclub performer in New Mexico (Kiki Walker) takes a leashed leopard into the club as a publicity gimmick. But her rival, angered by the attempt to upstage, scares the animal and it bolts. In the days that follow, people are mauled and the countryside is combed for the loose creature. But Kiki and her manager begin to wonder if maybe the leopard is not responsible for the killings.', 'languages': ['English', 'Spanish'], 'released': datetime.datetime(1943, 5, 8, 0, 0), 'directors': ['Jacques Tourneur'], 'writers': ['Ardel Wray (screenplay)', 'Edward Dein (additional dialogue)', 'Cornell Woolrich (novel)'], 'awards': {'wins': 0, 'nominations': 2, 'text': '2 nominations.'}, 'lastupdated': '2015-08-05 00:17:53.897000000', 'year': 1943, 'imdb': {'rating': 6.9, 'votes': 2889, 'id': 36104}, 'countries': ['USA'], 'type': 'movie', 'tomatoes': {'viewer': {'rating': 3.5, 'numReviews': 1375, 'meter': 67}, 'fresh': 15, 'critic': {'rating': 7.4, 'numReviews': 17, 'meter': 88}, 'rotten': 2, 'lastUpdated': datetime.datetime(2015, 8, 27, 18, 6, 2)}}
# {'_id': ObjectId('573a1393f29313caabcdd38c'), 'plot': 'A ruthless doctor and his young prize student find themselves continually harassed by their murderous supplier of illegal cadavers.', 'genres': ['Horror', 'Thriller'], 'runtime': 77, 'rated': 'APPROVED', 'title': 'The Body Snatcher', 'num_mflix_comments': 0, 'poster': 'https://m.media-amazon.com/images/M/MV5BNzNmOTE0YTktZGZmYS00N2RhLWI5NTgtYTAyZjZhYWExMmRmXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SY1000_SX677_AL_.jpg', 'countries': ['USA'], 'fullplot': "In Edinburgh in 1831, Dr. Wolfe MacFarlane runs a medical school where Donald Fettes is a student. Fettes is interested in helping a young girl who has lost the use of her legs. He is certain that MacFarlane's surgical skills could be put to great use but he is reluctant to do so. The good Dr. MacFarlane has a secret that soon becomes all too obvious to young Fettes, who has only recently been promoted as his assistant: he has been paying a local cabbie, John Gray, to supply him with dead bodies for anatomical research. Gray constantly harasses MacFarlane and clearly has a hold over him dating to a famous trial many years before where Gray refused to identify the man for whom he was robbing graves. Fettes isn't aware of any of this but soon realizes exactly how Gray obtains the bodies they use in their anatomy classes.", 'languages': ['English'], 'cast': ['Boris Karloff', 'Bela Lugosi', 'Henry Daniell', 'Edith Atwater'], 'directors': ['Robert Wise'], 'writers': ['Robert Louis Stevenson (short story)', 'Philip MacDonald (written for the screen by)', 'Val Lewton (written for the screen by)'], 'awards': {'wins': 0, 'nominations': 3, 'text': '3 nominations.'}, 'lastupdated': '2015-08-16 01:24:24.840000000', 'year': 1945, 'imdb': {'rating': 7.4, 'votes': 5509, 'id': 37549}, 'type': 'movie', 'tomatoes': {'viewer': {'rating': 3.5, 'numReviews': 3664, 'meter': 75}, 'critic': {'rating': 6.8, 'numReviews': 16, 'meter': 81}, 'lastUpdated': datetime.datetime(2015, 8, 21, 19, 11, 47), 'rotten': 3, 'production': 'RKO Pictures', 'fresh': 13}}
# {'_id': ObjectId('573a1393f29313caabcdd3ed'), 'plot': 'An architect senses impending doom as his half-remembered recurring dream turns into reality. The guests at the country house encourage him to stay as they take turns telling supernatural tales.', 'genres': ['Horror'], 'runtime': 77, 'rated': 'APPROVED', 'cast': ['Mervyn Johns', 'Roland Culver', 'Mary Merrall', 'Googie Withers'], 'num_mflix_comments': 0, 'poster': 'https://m.media-amazon.com/images/M/MV5BYTY2OTJjZjgtMzExMy00MWJlLTg2N2ItM2NhMDQxNTNkNjFhXkEyXkFqcGdeQXVyMjI4MjA5MzA@._V1_SY1000_SX677_AL_.jpg', 'title': 'Dead of Night', 'fullplot': "Architect Walter Craig, seeking the possibility of some work at a country farmhouse, soon finds himself once again stuck in his recurring nightmare. Dreading the end of the dream that he knows is coming, he must first listen to all the assembled guests' own bizarre tales.", 'languages': ['English', 'French'], 'released': datetime.datetime(1945, 10, 15, 0, 0), 'directors': ['Alberto Cavalcanti', 'Charles Crichton', 'Basil Dearden', 'Robert Hamer'], 'writers': ['H.G. Wells (original story)', 'E.F. Benson (original story)', 'John Baines (original story)', 'Angus MacPhail (original story)', 'John Baines (screenplay)', 'Angus MacPhail (screenplay)', 'T.E.B. Clarke (additional dialogue)'], 'awards': {'wins': 1, 'nominations': 1, 'text': '1 win & 1 nomination.'}, 'lastupdated': '2015-09-15 04:38:12.500000000', 'year': 1945, 'imdb': {'rating': 7.7, 'votes': 7116, 'id': 37635}, 'countries': ['UK'], 'type': 'movie', 'tomatoes': {'viewer': {'rating': 4.0, 'numReviews': 3194, 'meter': 88}, 'dvd': datetime.datetime(2009, 1, 27, 0, 0), 'critic': {'rating': 8.0, 'numReviews': 27, 'meter': 96}, 'lastUpdated': datetime.datetime(2015, 7, 26, 18, 40, 43), 'consensus': 'With four accomplished directors contributing, Dead of Night is a classic horror anthology that remains highly influential.', 'rotten': 1, 'production': 'Universal Pictures', 'fresh': 26}}
# {'_id': ObjectId('573a1393f29313caabcdd6e7'), 'plot': "Chuck Scott gets a job as chauffeur to tough guy Eddie Roman; but Chuck's involvement with Eddie's fearful wife becomes a nightmare.", 'genres': ['Film-Noir'], 'runtime': 86, 'rated': 'APPROVED', 'cast': ['Robert Cummings', 'Michèle Morgan', 'Steve Cochran', 'Lloyd Corrigan'], 'num_mflix_comments': 0, 'poster': 'https://m.media-amazon.com/images/M/MV5BNDI3OTM4NzMtNzQxMC00M2YxLWFmOTctNmUyNDBmMzIwZGI0XkEyXkFqcGdeQXVyMjUxODE0MDY@._V1_SY1000_SX677_AL_.jpg', 'title': 'The Chase', 'fullplot': "Returning a lost wallet gains unemployed veteran Chuck Scott a job as chauffeur to Eddie Roman, a seeming gangster whose enemies have a way of meeting violent ends. The job proves nerve-wracking, and soon Chuck finds himself pledged to help Eddie's lovely, fearful, prisoner-wife Lorna to escape. The result leaves Chuck caught like a rat in a trap, vainly seeking a way out through dark streets. But the real chase begins when the strange plot virtually starts all over again...", 'languages': ['English', 'Spanish'], 'released': datetime.datetime(1946, 11, 16, 0, 0), 'directors': ['Arthur Ripley'], 'writers': ['Philip Yordan (written for the screen by)', 'Cornell Woolrich (book)'], 'awards': {'wins': 0, 'nominations': 1, 'text': '1 nomination.'}, 'lastupdated': '2015-08-01 00:47:13.267000000', 'year': 1946, 'imdb': {'rating': 6.7, 'votes': 766, 'id': 38409}, 'countries': ['USA'], 'type': 'movie', 'tomatoes': {'viewer': {'rating': 3.2, 'numReviews': 92, 'meter': 40}, 'dvd': datetime.datetime(2003, 8, 5, 0, 0), 'production': 'VCI', 'lastUpdated': datetime.datetime(2015, 8, 20, 18, 14, 48)}}
# {'_id': ObjectId('573a1393f29313caabcde460'), 'plot': "Over-the-hill boxer Bill 'Stoker' Thompson insists he can still win, though his sexy wife Julie pleads with him to quit. But his manager Tiny is so confident he will lose, he takes money ...", 'genres': ['Film-Noir', 'Sport'], 'runtime': 73, 'rated': 'APPROVED', 'cast': ['Robert Ryan', 'Audrey Totter', 'George Tobias', 'Alan Baxter'], 'num_mflix_comments': 0, 'poster': 'https://m.media-amazon.com/images/M/MV5BMjEwNjU3NzE1Nl5BMl5BanBnXkFtZTgwMjQ0MDgyMTE@._V1_SY1000_SX677_AL_.jpg', 'title': 'The Set-Up', 'fullplot': 'Over-the-hill boxer Bill \'Stoker\' Thompson insists he can still win, though his sexy wife Julie pleads with him to quit. But his manager Tiny is so confident he will lose, he takes money for a "dive" from tough gambler Little Boy...without bothering to tell Stoker. Tension builds as Stoker hopes to "take" Tiger Nelson, unaware of what will happen to him if he does.', 'languages': ['English'], 'released': datetime.datetime(1949, 4, 2, 0, 0), 'directors': ['Robert Wise'], 'writers': ['Art Cohn (screenplay)', 'Joseph Moncure March (from the poem by)'], 'awards': {'wins': 3, 'nominations': 1, 'text': 'Nominated for 1 BAFTA Film Award. Another 2 wins & 1 nomination.'}, 'lastupdated': '2015-08-26 00:13:18.837000000', 'year': 1949, 'imdb': {'rating': 7.8, 'votes': 5309, 'id': 41859}, 'countries': ['USA'], 'type': 'movie', 'tomatoes': {'viewer': {'rating': 4.0, 'numReviews': 1692, 'meter': 88}, 'dvd': datetime.datetime(2004, 7, 6, 0, 0), 'critic': {'rating': 5.9, 'numReviews': 7, 'meter': 86}, 'lastUpdated': datetime.datetime(2015, 7, 26, 18, 33, 52), 'rotten': 1, 'fresh': 6}}

# %% [markdown]
# #### Задача 1.5 — **1 балл**

# %% [markdown]
# Модифицируйте запрос из задачи 1.4 таким образом, чтобы осуществить _проекцию_: результатом выборки должен стать список словарей, каждый из которых содержит только два поля: `title` и `year`.
#
# Для справки о проекции см. документацию по методу `find()` в pymongo:
# https://pymongo.readthedocs.io/en/stable/api/pymongo/collection.html#pymongo.collection.Collection.find

# %%
# Ваш код здесь
query = {
    "genres.0": {"$in" : ["Film-Noir", "Horror"]},
    "year": {"$gte": 1940, "$lte": 1949}
}

projection = {
    "_id": 0,
    "title": 1,
    "year": 1
}

results = movies_collection.find(query, projection)

for movie in results:
    print(movie)
# Out:
# {'title': 'Cat People', 'year': 1942}
# {'title': 'I Walked with a Zombie', 'year': 1943}
# {'title': 'The Leopard Man', 'year': 1943}
# {'title': 'The Body Snatcher', 'year': 1945}
# {'title': 'Dead of Night', 'year': 1945}
# {'title': 'The Chase', 'year': 1946}
# {'title': 'The Set-Up', 'year': 1949}

# %% [markdown]
# ### Упражнение 2. Конвейер агрегации

# %% [markdown]
# #### Задача 2.1 — **3 балла**

# %% [markdown]
# В рамках этой задачи требуется узнать, какие фильмы получили наибольшее число комментариев. Составьте для этого конвейер агрегации с перечисленными ниже этапами. Для удобства рекомендуется воспользоваться приложением Compass.
#
# 1. Сгруппировать документы коллекции `comments` по полю `movie_id` и подсчитать количество комментариев для каждого фильма, записав его в поле `count`.
# 1. Отсортировать получившийся набор данных по убыванию количества комментариев (так чтобы первый документ в этом наборе указывал на фильм с наибольшим количеством комментариев).
# 1. Используя оператор `$lookup`, присоединить коллекцию `movies` (по полю `movie_id`).
# 1. Выполнить проекцию, оставив в наборе данных только три поля: название фильма (`title`), год выпуска (`year`) и количество комментариев (поле `count`, добавленное на первом этапе). Для этого воспользуйтесь оператором `$project`: https://www.mongodb.com/docs/manual/reference/operator/aggregation/project/. Обратите внимание, что данные из коллекции `movies` (`title` и `year`) на этом этапе окажутся внутри массива.
# 1. Применить оператор `$unwind`, чтобы деконструировать этот массив. См. https://www.mongodb.com/docs/manual/reference/operator/aggregation/unwind/. В результате массив должен превратиться в одиночный объект.
# 1. Применить оператор `$addFields`, чтобы добавить поля `title` и `year` на вернхий уровень структуры документа. См. https://www.mongodb.com/docs/manual/reference/operator/aggregation/addFields/.
# 1. Еще раз выполнить проекцию, чтобы удалить поле с массивом.
#
# Ваш алгоритм решения может отличаться от приведенного здесь. Главное — достичь цели: получить плоский набор данных с тремя полями (`count` — количество комментариев, `year` — год выпуска, `title` — название фильма).
#
# Скопируйте полученный конвейер в этот документ в виде кода на Python и выведите его на экран в виде списка словарей.

# %%
pipeline = [
    {
        "$group": {
            "_id": "$movie_id",
            "count": {"$sum": 1}
        }
    },

    {
        "$sort": {"count": -1}
    },

    {
        "$lookup": {
            "from": "movies",
            "localField": "_id",
            "foreignField": "_id",
            "as": "movie_info"
        }
    },

    {
        "$unwind": "$movie_info"
    },

    {
        "$addFields": {
            "title": "$movie_info.title",
            "year": "$movie_info.year"
        }
    },

    {
        "$project": {
            "_id": 0,
            "title": 1,
            "year": 1,
            "count": 1
        }
    }
]


results = list(comments_collection.aggregate(pipeline))

for movie in results:
    print(movie)
# Out:
# {'count': 161, 'title': 'The Taking of Pelham 1 2 3', 'year': 2009}
# {'count': 158, 'title': 'About a Boy', 'year': 2002}
# {'count': 158, 'title': "Ocean's Eleven", 'year': 2001}
# {'count': 158, 'title': '50 First Dates', 'year': 2004}
# {'count': 158, 'title': 'Terminator Salvation', 'year': 2009}
# {'count': 157, 'title': 'Sherlock Holmes', 'year': 2009}
# {'count': 157, 'title': 'The Mummy', 'year': 1999}
# {'count': 155, 'title': 'Hellboy II: The Golden Army', 'year': 2008}
# {'count': 154, 'title': 'The Mummy Returns', 'year': 2001}
# {'count': 154, 'title': 'Anchorman: The Legend of Ron Burgundy', 'year': 2004}
# {'count': 153, 'title': "Pirates of the Caribbean: At World's End", 'year': 2007}
# {'count': 153, 'title': 'Bruce Almighty', 'year': 2003}
# {'count': 153, 'title': 'Mission: Impossible', 'year': 1996}
# {'count': 153, 'title': 'Wanted', 'year': 2008}
# {'count': 153, 'title': 'Cinderella', 'year': 1950}
# {'count': 153, 'title': 'X-Men', 'year': 2000}
# {'count': 153, 'title': 'E.T. the Extra-Terrestrial', 'year': 1982}
# {'count': 153, 'title': 'American Pie', 'year': 1999}
# {'count': 152, 'title': 'The Ring', 'year': 2002}
# {'count': 152, 'title': 'Gladiator', 'year': 2000}
# {'count': 151, 'title': 'The Matrix Reloaded', 'year': 2003}
# {'count': 151, 'title': 'Meet the Fockers', 'year': 2004}
# {'count': 151, 'title': 'The Mask', 'year': 1994}
# {'count': 150, 'title': 'Toy Story 2', 'year': 1999}
# {'count': 150, 'title': 'Big Daddy', 'year': 1999}
# {'count': 148, 'title': 'I Am Legend', 'year': 2007}
# {'count': 148, 'title': 'Jurassic Park', 'year': 1993}
# {'count': 148, 'title': 'Braveheart', 'year': 1995}
# {'count': 147, 'title': 'The Express', 'year': 2008}
# {'count': 147, 'title': 'Scary Movie', 'year': 2000}
# {'count': 147, 'title': 'Jaws', 'year': 1975}
# {'count': 146, 'title': 'Twister', 'year': 1996}
# {'count': 146, 'title': 'I Now Pronounce You Chuck & Larry', 'year': 2007}
# {'count': 145, 'title': '300', 'year': 2006}
# {'count': 145, 'title': 'Cast Away', 'year': 2000}
# {'count': 145, 'title': 'Dumb & Dumber', 'year': 1994}
# {'count': 144, 'title': 'Hostel: Part II', 'year': 2007}
# {'count': 144, 'title': 'The Simpsons Movie', 'year': 2007}
# {'count': 144, 'title': 'The Hangover', 'year': 2009}
# {'count': 144, 'title': 'School of Rock', 'year': 2003}
# {'count': 144, 'title': 'Zoolander', 'year': 2001}
# {'count': 144, 'title': 'Dègkeselyè', 'year': 1982}
# {'count': 144, 'title': 'Aladdin', 'year': 1992}
# {'count': 144, 'title': 'The Last House on the Left', 'year': 2009}
# {'count': 144, 'title': 'I Love You, Man', 'year': 2009}
# {'count': 144, 'title': 'The Green Mile', 'year': 1999}
# {'count': 144, 'title': 'Spider-Man 3', 'year': 2007}
# {'count': 144, 'title': 'Saving Private Ryan', 'year': 1998}
# {'count': 144, 'title': 'King Kong', 'year': 2005}
# {'count': 143, 'title': '8 Mile', 'year': 2002}
# {'count': 143, 'title': 'Up', 'year': 2009}
# {'count': 143, 'title': 'Kill Bill: Vol. 1', 'year': 2003}
# {'count': 143, 'title': 'Rush Hour 2', 'year': 2001}
# {'count': 143, 'title': 'Ice Age', 'year': 2002}
# {'count': 143, 'title': 'Harry Potter and the Chamber of Secrets', 'year': 2002}
# {'count': 143, 'title': 'The Jungle Creature: Hugo', 'year': 1993}
# {'count': 142, 'title': 'Back to the Future Part II', 'year': 1989}
# {'count': 142, 'title': 'Speed', 'year': 1994}
# {'count': 142, 'title': 'Shutter Island', 'year': 2010}
# {'count': 142, 'title': "Ocean's Twelve", 'year': 2004}
# {'count': 142, 'title': 'Star Trek', 'year': 2009}
# {'count': 141, 'title': 'Live Free or Die Hard', 'year': 2007}
# {'count': 141, 'title': 'Freaky Friday', 'year': 2003}
# {'count': 141, 'title': 'Rush Hour', 'year': 1998}
# {'count': 141, 'title': 'Billy Madison', 'year': 1995}
# {'count': 141, 'title': 'The Princess Diaries', 'year': 2001}
# {'count': 141, 'title': '1408', 'year': 2007}
# {'count': 141, 'title': 'Evan Almighty', 'year': 2007}
# {'count': 140, 'title': 'Mr. & Mrs. Smith', 'year': 2005}
# {'count': 140, 'title': 'Men in Black II', 'year': 2002}
# {'count': 140, 'title': 'X-Men 2', 'year': 2003}
# {'count': 140, 'title': 'War of the Worlds', 'year': 2005}
# {'count': 140, 'title': 'Back to the Future Part III', 'year': 1990}
# {'count': 140, 'title': 'Cheaper by the Dozen', 'year': 2003}
# {'count': 140, 'title': 'Ghost Rider', 'year': 2007}
# {'count': 140, 'title': 'The Bourne Ultimatum', 'year': 2007}
# {'count': 139, 'title': 'V for Vendetta', 'year': 2005}
# {'count': 139, 'title': 'Happy Gilmore', 'year': 1996}
# {'count': 139, 'title': 'Ace Ventura: When Nature Calls', 'year': 1995}
# {'count': 139, 'title': 'Liar Liar', 'year': 1997}
# {'count': 139, 'title': 'The Wizard of Oz', 'year': 1939}
# {'count': 139, 'title': 'The Matrix Revolutions', 'year': 2003}
# {'count': 139, 'title': 'Saw VI', 'year': 2009}
# {'count': 138, 'title': 'Shark Tale', 'year': 2004}
# {'count': 138, 'title': 'The Matrix', 'year': 1999}
# {'count': 138, 'title': 'Sweeney Todd: The Demon Barber of Fleet Street', 'year': 2007}
# {'count': 138, 'title': 'How to Lose a Guy in 10 Days', 'year': 2003}
# {'count': 138, 'title': 'Donnie Darko', 'year': 2001}
# {'count': 138, 'title': "Harry Potter and the Sorcerer's Stone", 'year': 2001}
# {'count': 138, 'title': 'Gone in Sixty Seconds', 'year': 2000}
# {'count': 138, 'title': 'Men in Black 3', 'year': 2012}
# {'count': 138, 'title': 'A Christmas Carol', 'year': 2009}
# {'count': 138, 'title': 'How the Grinch Stole Christmas', 'year': 2000}
# {'count': 137, 'title': 'Elf', 'year': 2003}
# {'count': 137, 'title': 'Fight Club', 'year': 1999}
# {'count': 137, 'title': 'Star Wars: Episode III - Revenge of the Sith', 'year': 2005}
# {'count': 137, 'title': 'The 40-Year-Old Virgin', 'year': 2005}
# {'count': 137, 'title': 'My Big Fat Greek Wedding', 'year': 2002}
# {'count': 137, 'title': 'Independence Day', 'year': 1996}
# {'count': 136, 'title': 'The Waterboy', 'year': 1998}
# {'count': 136, 'title': 'Beetlejuice', 'year': 1988}
# {'count': 136, 'title': 'Rocky', 'year': 1976}
# {'count': 136, 'title': 'The Bourne Identity', 'year': 2002}
# {'count': 136, 'title': 'Forrest Gump', 'year': 1994}
# {'count': 136, 'title': 'Harry Potter and the Prisoner of Azkaban', 'year': 2004}
# {'count': 136, 'title': 'Cast Away', 'year': 2000}
# {'count': 136, 'title': 'The Nightmare Before Christmas', 'year': 1993}
# {'count': 136, 'title': 'The Dark Knight', 'year': 2008}
# {'count': 135, 'title': 'Push', 'year': 2009}
# {'count': 135, 'title': 'Signs', 'year': 2002}
# {'count': 135, 'title': 'Indiana Jones and the Last Crusade', 'year': 1989}
# {'count': 135, 'title': 'Bring It On', 'year': 2000}
# {'count': 135, 'title': 'The Chronicles of Narnia: The Lion, the Witch and the Wardrobe', 'year': 2005}
# {'count': 135, 'title': 'Honey, I Shrunk the Kids', 'year': 1989}
# {'count': 134, 'title': 'Fantastic Four', 'year': 2005}
# {'count': 134, 'title': 'American Pie 2', 'year': 2001}
# {'count': 134, 'title': 'Miss Congeniality', 'year': 2000}
# {'count': 134, 'title': 'The Uninvited', 'year': 2009}
# {'count': 134, 'title': 'Fantastic 4: Rise of the Silver Surfer', 'year': 2007}
# {'count': 134, 'title': 'Monsters, Inc.', 'year': 2001}
# {'count': 134, 'title': 'Beauty and the Beast', 'year': 1991}
# {'count': 134, 'title': 'Sin City', 'year': 2005}
# {'count': 134, 'title': 'The Mummy', 'year': 1999}
# {'count': 134, 'title': 'Spider-Man 2', 'year': 2004}
# {'count': 134, 'title': 'The Jungle Book', 'year': 1967}
# {'count': 134, 'title': 'Transformers: Revenge of the Fallen', 'year': 2009}
# {'count': 133, 'title': 'The Ugly Truth', 'year': 2009}
# {'count': 133, 'title': 'The Fast and the Furious', 'year': 2001}
# {'count': 133, 'title': 'The Lord of the Rings: The Return of the King', 'year': 2003}
# {'count': 133, 'title': 'Blades of Glory', 'year': 2007}
# {'count': 133, 'title': 'Shrek 2', 'year': 2004}
# {'count': 132, 'title': 'Men in Black', 'year': 1997}
# {'count': 132, 'title': 'The Lion King', 'year': 1994}
# {'count': 132, 'title': 'Free Willy', 'year': 1993}
# {'count': 132, 'title': 'Ace Ventura: Pet Detective', 'year': 1994}
# {'count': 132, 'title': "The Time Traveler's Wife", 'year': 2009}
# {'count': 132, 'title': 'Catch Me If You Can', 'year': 2002}
# {'count': 132, 'title': 'Shrek the Third', 'year': 2007}
# {'count': 132, 'title': '2 Fast 2 Furious', 'year': 2003}
# {'count': 131, 'title': 'The Sixth Sense', 'year': 1999}
# {'count': 131, 'title': 'American Beauty', 'year': 1999}
# {'count': 131, 'title': 'Meet the Parents', 'year': 2000}
# {'count': 131, 'title': 'Drag Me to Hell', 'year': 2009}
# {'count': 131, 'title': 'Toy Story', 'year': 1995}
# {'count': 131, 'title': 'Doctor Dolittle', 'year': 1998}
# {'count': 131, 'title': 'Shrek', 'year': 2001}
# {'count': 131, 'title': 'Star Wars: Episode IV - A New Hope', 'year': 1977}
# {'count': 131, 'title': 'The Godfather', 'year': 1972}
# {'count': 131, 'title': 'The Unborn', 'year': 2009}
# {'count': 131, 'title': 'The Shawshank Redemption', 'year': 1994}
# {'count': 131, 'title': 'Shark Tale', 'year': 2004}
# {'count': 130, 'title': 'Ice Age: The Meltdown', 'year': 2006}
# {'count': 130, 'title': 'G.I. Joe: The Rise of Cobra', 'year': 2009}
# {'count': 130, 'title': 'Hook', 'year': 1991}
# {'count': 130, 'title': 'Home Alone', 'year': 1990}
# {'count': 130, 'title': 'Pretty Woman', 'year': 1990}
# {'count': 130, 'title': 'The Day After Tomorrow', 'year': 2004}
# {'count': 129, 'title': 'Bad Boys', 'year': 1995}
# {'count': 129, 'title': 'Avatar', 'year': 2009}
# {'count': 129, 'title': 'The Dark Knight Rises', 'year': 2012}
# {'count': 128, 'title': 'The Curious Case of Benjamin Button', 'year': 2008}
# {'count': 128, 'title': 'X-Men', 'year': 2000}
# {'count': 128, 'title': 'The Little Mermaid', 'year': 1989}
# {'count': 128, 'title': 'A Walk to Remember', 'year': 2002}
# {'count': 128, 'title': 'A Cinderella Story', 'year': 2004}
# {'count': 128, 'title': 'Stop-Loss', 'year': 2008}
# {'count': 128, 'title': 'Mary Poppins', 'year': 1964}
# {'count': 128, 'title': 'Titanic', 'year': 1997}
# {'count': 128, 'title': 'Night at the Museum', 'year': 2006}
# {'count': 128, 'title': 'Liar Liar', 'year': 1997}
# {'count': 128, 'title': 'Troy', 'year': 2004}
# {'count': 128, 'title': 'Mr. Deeds', 'year': 2002}
# {'count': 128, 'title': 'Sister Act', 'year': 1992}
# {'count': 128, 'title': 'Austin Powers: International Man of Mystery', 'year': 1997}
# {'count': 127, 'title': 'The Lord of the Rings: The Two Towers', 'year': 2002}
# {'count': 127, 'title': 'Funny People', 'year': 2009}
# {'count': 127, 'title': 'The Wedding Singer', 'year': 1998}
# {'count': 127, 'title': 'Pirates of the Caribbean: The Curse of the Black Pearl', 'year': 2003}
# {'count': 127, 'title': 'Slumdog Millionaire', 'year': 2008}
# {'count': 127, 'title': 'Taken', 'year': 2008}
# {'count': 127, 'title': 'The Incredible Hulk', 'year': 2008}
# {'count': 127, 'title': 'Inglourious Basterds', 'year': 2009}
# {'count': 126, 'title': 'Anger Management', 'year': 2003}
# {'count': 126, 'title': 'Austin Powers in Goldmember', 'year': 2002}
# {'count': 126, 'title': 'Mrs. Doubtfire', 'year': 1993}
# {'count': 126, 'title': 'Lady and the Tramp', 'year': 1955}
# {'count': 126, 'title': 'Raiders of the Lost Ark', 'year': 1981}
# {'count': 125, 'title': 'Terminator 2: Judgment Day', 'year': 1991}
# {'count': 125, 'title': 'Batman', 'year': 1989}
# {'count': 125, 'title': 'Pearl Harbor', 'year': 2001}
# {'count': 124, 'title': 'Austin Powers: The Spy Who Shagged Me', 'year': 1999}
# {'count': 124, 'title': 'Armageddon', 'year': 1998}
# {'count': 123, 'title': 'Scary Movie', 'year': 2000}
# {'count': 123, 'title': 'Harry Potter and the Half-Blood Prince', 'year': 2009}
# {'count': 123, 'title': 'Cars', 'year': 2006}
# {'count': 123, 'title': 'National Treasure: Book of Secrets', 'year': 2007}
# {'count': 122, 'title': 'The Proposal', 'year': 2009}
# {'count': 122, 'title': 'Fighting', 'year': 2009}
# {'count': 122, 'title': 'The Stepfather', 'year': 2009}
# {'count': 122, 'title': 'The End of a Mystery', 'year': 2003}
# {'count': 122, 'title': "Ocean's Thirteen", 'year': 2007}
# {'count': 122, 'title': 'The Shawshank Redemption', 'year': 1994}
# {'count': 121, 'title': 'Quarantine', 'year': 2008}
# {'count': 121, 'title': 'The Invention of Lying', 'year': 2009}
# {'count': 121, 'title': 'The Silence of the Lambs', 'year': 1991}
# {'count': 121, 'title': 'Pulp Fiction', 'year': 1994}
# {'count': 121, 'title': "A Bug's Life", 'year': 1998}
# {'count': 121, 'title': 'G-Force', 'year': 2009}
# {'count': 121, 'title': 'Madagascar', 'year': 2005}
# {'count': 120, 'title': 'Finding Nemo', 'year': 2003}
# {'count': 120, 'title': 'Willy Wonka & the Chocolate Factory', 'year': 1971}
# {'count': 119, 'title': 'Grease', 'year': 1978}
# {'count': 119, 'title': 'Watchmen', 'year': 2009}
# {'count': 119, 'title': '10 Things I Hate About You', 'year': 1999}
# {'count': 119, 'title': 'Jumanji', 'year': 1995}
# {'count': 119, 'title': 'Harry Potter and the Goblet of Fire', 'year': 2005}
# {'count': 119, 'title': 'The Hunger Games', 'year': 2012}
# {'count': 118, 'title': '101 Dalmatians', 'year': 1961}
# {'count': 117, 'title': 'Star Wars: Episode II - Attack of the Clones', 'year': 2002}
# {'count': 117, 'title': 'Orphan', 'year': 2009}
# {'count': 117, 'title': 'The Avengers', 'year': 2012}
# {'count': 117, 'title': 'Saw II', 'year': 2005}
# {'count': 116, 'title': 'Scary Movie 3', 'year': 2003}
# {'count': 116, 'title': 'Love Actually', 'year': 2003}
# {'count': 115, 'title': 'Scary Movie 2', 'year': 2001}
# {'count': 115, 'title': 'Borat: Cultural Learnings of America for Make Benefit Glorious Nation of Kazakhstan', 'year': 2006}
# {'count': 115, 'title': 'Sweet Home Alabama', 'year': 2002}
# {'count': 115, 'title': 'The Departed', 'year': 2006}
# {'count': 115, 'title': 'Dirty Dancing', 'year': 1987}
# {'count': 115, 'title': 'Edward Scissorhands', 'year': 1990}
# {'count': 115, 'title': 'Star Wars: Episode V - The Empire Strikes Back', 'year': 1980}
# {'count': 115, 'title': 'How to Lose a Guy in 10 Days', 'year': 2003}
# {'count': 114, 'title': 'The Lord of the Rings: The Fellowship of the Ring', 'year': 2001}
# {'count': 114, 'title': 'Hairspray', 'year': 2007}
# {'count': 113, 'title': 'Disturbia', 'year': 2007}
# {'count': 111, 'title': "Charlie's Angels", 'year': 2000}
# {'count': 111, 'title': 'District 9', 'year': 2009}
# {'count': 111, 'title': 'Coyote Ugly', 'year': 2000}
# {'count': 111, 'title': 'American Gangster', 'year': 2007}
# {'count': 109, 'title': 'The Amazing Spider-Man', 'year': 2012}
# {'count': 108, 'title': 'Home Alone 2: Lost in New York', 'year': 1992}
# {'count': 107, 'title': 'Norbit', 'year': 2007}
# {'count': 5, 'title': 'The Cure', 'year': 1995}
# {'count': 4, 'title': 'Cowards Bend the Knee or The Blue Hands', 'year': 2003}
# {'count': 4, 'title': 'Compliance', 'year': 2012}
# {'count': 4, 'title': 'The Women', 'year': 2008}
# {'count': 4, 'title': 'Play It Again, Sam', 'year': 1972}
# {'count': 4, 'title': 'Splice', 'year': 2009}
# {'count': 4, 'title': 'Night Catches Us', 'year': 2010}
# {'count': 3, 'title': 'Exte: Hair Extensions', 'year': 2007}
# {'count': 3, 'title': 'La Cage aux Folles', 'year': 1978}
# {'count': 3, 'title': 'Moebius', 'year': 1996}
# {'count': 3, 'title': 'Metrobranding', 'year': 2010}
# {'count': 3, 'title': "Je t'aime je t'aime", 'year': 1968}
# {'count': 3, 'title': 'From Beyond', 'year': 1986}
# {'count': 3, 'title': 'Great Migrations', 'year': 2010}
# {'count': 3, 'title': 'The Roman Spring of Mrs. Stone', 'year': 1961}
# {'count': 3, 'title': 'Midnight Lace', 'year': 1960}
# {'count': 3, 'title': 'Kiss Kiss Bang Bang', 'year': 2005}
# {'count': 3, 'title': 'Slice', 'year': 2009}
# {'count': 3, 'title': 'The Terminal', 'year': 2004}
# {'count': 3, 'title': 'Peter and Vandy', 'year': 2009}
# {'count': 3, 'title': 'The Rising Place', 'year': 2001}
# {'count': 3, 'title': 'Cairo Time', 'year': 2009}
# {'count': 3, 'title': 'Footsteps in the Fog', 'year': 1955}
# {'count': 3, 'title': 'Twice in a Lifetime', 'year': 1985}
# {'count': 3, 'title': 'Hitler: The Rise of Evil', 'year': 2003}
# {'count': 3, 'title': 'Jesse Stone: Benefit of the Doubt', 'year': 2012}
# {'count': 3, 'title': 'Cesar Chavez', 'year': 2014}
# {'count': 3, 'title': 'Metalhead', 'year': 2013}
# {'count': 3, 'title': 'Nas: Time Is Illmatic', 'year': 2014}
# {'count': 3, 'title': 'Dig!', 'year': 2004}
# {'count': 3, 'title': 'Good Neighbors', 'year': 2010}
# {'count': 3, 'title': 'American Courtesans', 'year': 2013}
# {'count': 3, 'title': 'Comeback Season', 'year': 2006}
# {'count': 3, 'title': 'Happenstance', 'year': 2000}
# {'count': 3, 'title': 'Max Dugan Returns', 'year': 1983}
# {'count': 3, 'title': 'Bionicle 3: Web of Shadows', 'year': 2005}
# {'count': 3, 'title': 'A Wife Confesses', 'year': 1961}
# {'count': 3, 'title': 'Cube Zero', 'year': 2004}
# {'count': 3, 'title': 'City of Men', 'year': 2007}
# {'count': 3, 'title': 'Duck, You Sucker', 'year': 1971}
# {'count': 3, 'title': 'The House', 'year': 1997}
# {'count': 3, 'title': 'The Boys of St. Vincent', 'year': 1992}
# {'count': 3, 'title': 'Bartok the Magnificent', 'year': 1999}
# {'count': 3, 'title': 'Federal Hill', 'year': 1994}
# {'count': 3, 'title': 'I Am So Proud of You', 'year': 2008}
# {'count': 3, 'title': 'Beauty Day', 'year': 2011}
# {'count': 3, 'title': 'Plastic', 'year': 2014}
# {'count': 3, 'title': 'Obitaemyy ostrov. Skhvatka', 'year': 2009}
# {'count': 3, 'title': 'The Unknown Woman', 'year': 2011}
# {'count': 3, 'title': 'The Saboteurs', 'year': 2015}
# {'count': 3, 'title': 'Bride Wars', 'year': 2009}
# {'count': 3, 'title': 'The Promised Land', 'year': 1975}
# {'count': 3, 'title': 'The Dark Side of Chocolate', 'year': 2010}
# {'count': 3, 'title': "Everybody's Famous!", 'year': 2000}
# {'count': 3, 'title': 'Honey I Blew Up the Kid', 'year': 1992}
# {'count': 3, 'title': 'Bleak Night', 'year': 2010}
# {'count': 3, 'title': 'Black Cloud', 'year': 2004}
# {'count': 3, 'title': 'Return to Paradise', 'year': 1998}
# {'count': 3, 'title': 'The Cincinnati Kid', 'year': 1965}
# {'count': 3, 'title': 'Silent Running', 'year': 1972}
# {'count': 3, 'title': 'Gangster Squad', 'year': 2013}
# {'count': 3, 'title': 'Return of the Living Dead III', 'year': 1993}
# {'count': 3, 'title': 'Ten Skies', 'year': 2004}
# {'count': 3, 'title': 'The Mighty Ducks', 'year': 1992}
# {'count': 3, 'title': 'Green Dragon', 'year': 2001}
# {'count': 3, 'title': 'The Apartment', 'year': 1960}
# {'count': 3, 'title': 'Epic Movie', 'year': 2007}
# {'count': 3, 'title': 'Upstream', 'year': 1927}
# {'count': 3, 'title': 'Deterrence', 'year': 1999}
# {'count': 3, 'title': 'Syriana', 'year': 2005}
# {'count': 3, 'title': "Dead Man's Walk", 'year': 1996}
# {'count': 3, 'title': 'Misconception', 'year': 2014}
# {'count': 3, 'title': "The King's Speech", 'year': 2010}
# {'count': 3, 'title': "Jackie Chan's First Strike", 'year': 1996}
# {'count': 3, 'title': 'High Spirits', 'year': 1988}
# {'count': 3, 'title': 'Palimpsest', 'year': 2006}
# {'count': 3, 'title': 'Roots', 'year': 1977}
# {'count': 3, 'title': 'Never Tear Us Apart: The Untold Story of INXS', 'year': 2014}
# {'count': 3, 'title': 'Amistad', 'year': 1997}
# {'count': 3, 'title': '3 1/2 Minutes, Ten Bullets', 'year': 2015}
# {'count': 3, 'title': 'Chronicle of Poor Lovers', 'year': 1954}
# {'count': 3, 'title': "Betsy's Wedding", 'year': 1990}
# {'count': 3, 'title': 'Rabbit è la Berlin', 'year': 2009}
# {'count': 3, 'title': 'Chile, the Obstinate Memory', 'year': 1997}
# {'count': 3, 'title': 'Stand Clear of the Closing Doors', 'year': 2013}
# {'count': 3, 'title': 'The House by the Lake', 'year': 1976}
# {'count': 3, 'title': 'Horror Express', 'year': 1972}
# {'count': 3, 'title': 'La buena nueva', 'year': 2008}
# {'count': 3, 'title': '61*', 'year': 2001}
# {'count': 3, 'title': 'Someone Like You', 'year': 2009}
# {'count': 3, 'title': 'Robin-B-Hood', 'year': 2006}
# {'count': 3, 'title': 'Black Robe', 'year': 1991}
# {'count': 3, 'title': 'Lord of Darkness', 'year': 2012}
# {'count': 3, 'title': 'Jibeuro ganeun gil', 'year': 2013}
# {'count': 3, 'title': 'Inherent Vice', 'year': 2014}
# {'count': 3, 'title': 'Werner - Beinhart!', 'year': 1990}
# {'count': 3, 'title': 'The Boxer', 'year': 1997}
# {'count': 3, 'title': 'Mystery Men', 'year': 1999}
# {'count': 3, 'title': 'Nacho Libre', 'year': 2006}
# {'count': 3, 'title': 'The Cow', 'year': 1989}
# {'count': 3, 'title': 'King & Country', 'year': 1964}
# {'count': 3, 'title': 'Without Men', 'year': 2011}
# {'count': 3, 'title': 'Jurassic Park III', 'year': 2001}
# {'count': 3, 'title': 'Scott Joplin', 'year': 1977}
# {'count': 3, 'title': 'Macario', 'year': 1960}
# {'count': 3, 'title': 'Date Night', 'year': 2010}
# {'count': 3, 'title': 'Yesterday, Today and Tomorrow', 'year': 1963}
# {'count': 3, 'title': 'Euridice BA 2O37', 'year': 1975}
# {'count': 3, 'title': 'Bringing Ashley Home', 'year': 2011}
# {'count': 3, 'title': 'The Moth Diaries', 'year': 2011}
# {'count': 3, 'title': 'They Are All Dead', 'year': 2014}
# {'count': 3, 'title': 'Naming Number Two', 'year': 2006}
# {'count': 3, 'title': 'When Good Ghouls Go Bad', 'year': 2001}
# {'count': 3, 'title': 'SAGA: Curse of the Shadow', 'year': 2013}
# {'count': 3, 'title': 'The Shaman', 'year': 2015}
# {'count': 3, 'title': 'Monster High: Friday Night Frights', 'year': 2013}
# {'count': 3, 'title': 'Drifting Clouds', 'year': 1996}
# {'count': 3, 'title': 'Olympus Has Fallen', 'year': 2013}
# {'count': 3, 'title': '45 Years', 'year': 2015}
# {'count': 3, 'title': 'Batman: Gotham Knight', 'year': 2008}
# {'count': 3, 'title': 'The Valet', 'year': 2006}
# {'count': 3, 'title': "Occupe-toi d'Amèlie..!", 'year': 1949}
# {'count': 3, 'title': 'Exists', 'year': 2014}
# {'count': 3, 'title': 'Pom Poko', 'year': 1994}
# {'count': 3, 'title': 'Christmas in Connecticut', 'year': 1992}
# {'count': 3, 'title': 'Bonhoeffer: Agent of Grace', 'year': 2000}
# {'count': 3, 'title': 'Forgotten Silver', 'year': 1995}
# {'count': 3, 'title': '3rd World Hero', 'year': 2000}
# {'count': 3, 'title': 'Midnight FM', 'year': 2010}
# {'count': 3, 'title': 'The Dark House', 'year': 2009}
# {'count': 3, 'title': 'The Motorcycle Diaries', 'year': 2004}
# {'count': 3, 'title': 'Cold Feet', 'year': 1989}
# {'count': 3, 'title': 'Wah-Wah', 'year': 2005}
# {'count': 3, 'title': "That's Entertainment, Part II", 'year': 1976}
# {'count': 3, 'title': 'Duelul', 'year': 1981}
# {'count': 3, 'title': 'Tired Moonlight', 'year': 2015}
# {'count': 3, 'title': 'Proteus', 'year': 2003}
# {'count': 3, 'title': 'A True Mob Story', 'year': 1998}
# {'count': 3, 'title': 'Taira Clan Saga', 'year': 1955}
# {'count': 3, 'title': "Lilian's Story", 'year': 1996}
# {'count': 3, 'title': 'Mr. Average', 'year': 2006}
# {'count': 3, 'title': 'Pink Saris', 'year': 2010}
# {'count': 3, 'title': 'Overheard 2', 'year': 2011}
# {'count': 2, 'title': 'Enamorada', 'year': 1946}
# {'count': 2, 'title': 'Isadora', 'year': 1968}
# {'count': 2, 'title': 'The Bridge of San Luis Rey', 'year': 2004}
# {'count': 2, 'title': 'Nil by Mouth', 'year': 1997}
# {'count': 2, 'title': 'Beaches', 'year': 1988}
# {'count': 2, 'title': 'One-Minute Time Machine', 'year': 2014}
# {'count': 2, 'title': 'The Numbers Station', 'year': 2013}
# {'count': 2, 'title': 'Hell and Back Again', 'year': 2011}
# {'count': 2, 'title': 'The Forgotten', 'year': 2004}
# {'count': 2, 'title': 'Lucky Luke and the Daltons', 'year': 2004}
# {'count': 2, 'title': 'Dirty Pictures', 'year': 2000}
# {'count': 2, 'title': 'The Awakening', 'year': 2011}
# {'count': 2, 'title': 'Bangkok Hilton', 'year': 1989}
# {'count': 2, 'title': 'Room for One More', 'year': 1952}
# {'count': 2, 'title': 'Always', 'year': 1989}
# {'count': 2, 'title': 'The Great Santini', 'year': 1979}
# {'count': 2, 'title': 'The Kiss', 'year': 1988}
# {'count': 2, 'title': 'Ambassada', 'year': 2013}
# {'count': 2, 'title': 'Arthur Christmas', 'year': 2011}
# {'count': 2, 'title': 'Police Academy 5: Assignment: Miami Beach', 'year': 1988}
# {'count': 2, 'title': 'How Do You Know', 'year': 2010}
# {'count': 2, 'title': 'Pyaar Impossible!', 'year': 2010}
# {'count': 2, 'title': 'One Fine Day', 'year': 1996}
# {'count': 2, 'title': 'Ivy', 'year': 2015}
# {'count': 2, 'title': 'The Signal', 'year': 2007}
# {'count': 2, 'title': 'Semi-Pro', 'year': 2008}
# {'count': 2, 'title': 'China Girl', 'year': 1987}
# {'count': 2, 'title': 'Sarkar Raj', 'year': 2008}
# {'count': 2, 'title': 'Moonrise Kingdom', 'year': 2012}
# {'count': 2, 'title': 'Marnie', 'year': 1964}
# {'count': 2, 'title': 'Dear Guest, When Will You Leave?', 'year': 2010}
# {'count': 2, 'title': 'Never Met Picasso', 'year': 1996}
# {'count': 2, 'title': 'Life, Autumn', 'year': 1999}
# {'count': 2, 'title': 'Jitters', 'year': 2010}
# {'count': 2, 'title': "Girls Can't Swim", 'year': 2000}
# {'count': 2, 'title': "Winky's Horse", 'year': 2005}
# {'count': 2, 'title': 'A Slipping-Down Life', 'year': 1999}
# {'count': 2, 'title': 'Motorway', 'year': 2012}
# {'count': 2, 'title': 'Return to Oz', 'year': 1985}
# {'count': 2, 'title': 'Devdas', 'year': 2002}
# {'count': 2, 'title': 'Hardcore', 'year': 2004}
# {'count': 2, 'title': 'Men Vs Women', 'year': 2010}
# {'count': 2, 'title': 'Two for the Seesaw', 'year': 1962}
# {'count': 2, 'title': 'Primal Fear', 'year': 1996}
# {'count': 2, 'title': 'Catfish in Black Bean Sauce', 'year': 1999}
# {'count': 2, 'title': 'Eight Men Out', 'year': 1988}
# {'count': 2, 'title': 'Love Is My Profession', 'year': 1958}
# {'count': 2, 'title': 'Teenage', 'year': 2013}
# {'count': 2, 'title': 'Pulse', 'year': 2001}
# {'count': 2, 'title': 'Balance', 'year': 1989}
# {'count': 2, 'title': 'Stavisky...', 'year': 1974}
# {'count': 2, 'title': 'Gas, Inspector Palmu!', 'year': 1961}
# {'count': 2, 'title': 'La vendedora de rosas', 'year': 1998}
# {'count': 2, 'title': 'In the Name of the Law', 'year': 1949}
# {'count': 2, 'title': 'Spice World', 'year': 1997}
# {'count': 2, 'title': 'The Children', 'year': 2008}
# {'count': 2, 'title': 'Mystery Road', 'year': 2013}
# {'count': 2, 'title': 'Yesterday Was a Lie', 'year': 2008}
# {'count': 2, 'title': 'Mouth to Mouth', 'year': 2005}
# {'count': 2, 'title': 'Large', 'year': 2001}
# {'count': 2, 'title': 'The Paper Brigade', 'year': 1996}
# {'count': 2, 'title': 'Quo Vadis, Baby?', 'year': 2005}
# {'count': 2, 'title': 'The Mirror', 'year': 1997}
# {'count': 2, 'title': "I Don't Buy Kisses Anymore", 'year': 1992}
# {'count': 2, 'title': 'Rude Boy', 'year': 1980}
# {'count': 2, 'title': 'Beautiful Creatures', 'year': 2013}
# {'count': 2, 'title': 'Nowhere Boy', 'year': 2009}
# {'count': 2, 'title': 'The War', 'year': 2007}
# {'count': 2, 'title': 'Better Than Chocolate', 'year': 1999}
# {'count': 2, 'title': 'Kafka', 'year': 1991}
# {'count': 2, 'title': 'Triumph Over Violence', 'year': 1965}
# {'count': 2, 'title': 'The Girl and Death', 'year': 2012}
# {'count': 2, 'title': 'God Is Brazilian', 'year': 2003}
# {'count': 2, 'title': 'China Seas', 'year': 1935}
# {'count': 2, 'title': 'Messi', 'year': 2014}
# {'count': 2, 'title': 'A Life Less Ordinary', 'year': 1997}
# {'count': 2, 'title': 'The Road to Love', 'year': 2001}
# {'count': 2, 'title': 'Kiss Me in the Rain', 'year': 1999}
# {'count': 2, 'title': 'Goyokin', 'year': 1969}
# {'count': 2, 'title': "Child's Play 2", 'year': 1990}
# {'count': 2, 'title': 'Ghost World', 'year': 2001}
# {'count': 2, 'title': 'Dead Man Talking', 'year': 2012}
# {'count': 2, 'title': 'American Promise', 'year': 2013}
# {'count': 2, 'title': 'Animal Factory', 'year': 2000}
# {'count': 2, 'title': 'Century of Birthing', 'year': 2011}
# {'count': 2, 'title': 'Our Song', 'year': 2000}
# {'count': 2, 'title': 'EuroTrip', 'year': 2004}
# {'count': 2, 'title': 'To Rome with Love', 'year': 2012}
# {'count': 2, 'title': 'Blackrock', 'year': 1997}
# {'count': 2, 'title': 'Pierrepoint: The Last Hangman', 'year': 2005}
# {'count': 2, 'title': 'Wings of Desire', 'year': 1987}
# {'count': 2, 'title': 'Twins', 'year': 1988}
# {'count': 2, 'title': 'The Carey Treatment', 'year': 1972}
# {'count': 2, 'title': 'El amor brujo', 'year': 1986}
# {'count': 2, 'title': 'Richard Pryor: Omit the Logic', 'year': 2013}
# {'count': 2, 'title': 'Asterix and the Vikings', 'year': 2006}
# {'count': 2, 'title': 'Brother', 'year': 2000}
# {'count': 2, 'title': "Marie's Story", 'year': 2014}
# {'count': 2, 'title': 'Midnight Express', 'year': 1978}
# {'count': 2, 'title': 'Speed 2: Cruise Control', 'year': 1997}
# {'count': 2, 'title': 'The Goddess of 1967', 'year': 2000}
# {'count': 2, 'title': 'My Good Enemy', 'year': 2010}
# {'count': 2, 'title': 'Flirting with Disaster', 'year': 1996}
# {'count': 2, 'title': 'Big Trouble in Little China', 'year': 1986}
# {'count': 2, 'title': 'Downeast', 'year': 2012}
# {'count': 2, 'title': 'Carrie', 'year': 2013}
# {'count': 2, 'title': 'Somewhere Under the Broad Sky', 'year': 1954}
# {'count': 2, 'title': 'The House of Small Cubes', 'year': 2008}
# {'count': 2, 'title': 'Last Days', 'year': 2005}
# {'count': 2, 'title': 'The Out of Towners', 'year': 1970}
# {'count': 2, 'title': 'Motherhood', 'year': 2009}
# {'count': 2, 'title': 'The Education of Fairies', 'year': 2006}
# {'count': 2, 'title': 'Powder', 'year': 1995}
# {'count': 2, 'title': 'Love in the Time of Money', 'year': 2002}
# {'count': 2, 'title': 'Il minestrone', 'year': 1981}
# {'count': 2, 'title': 'Fort Tilden', 'year': 2014}
# {'count': 2, 'title': 'Chaotic Ana', 'year': 2007}
# {'count': 2, 'title': 'The Pentagon Papers', 'year': 2003}
# {'count': 2, 'title': 'Youth', 'year': 2015}
# {'count': 2, 'title': '4 Elements', 'year': 2006}
# {'count': 2, 'title': 'Islander', 'year': 2007}
# {'count': 2, 'title': 'Beavis and Butt-Head Do America', 'year': 1996}
# {'count': 2, 'title': 'StarStruck', 'year': 2010}
# {'count': 2, 'title': 'Delicacy', 'year': 2011}
# {'count': 2, 'title': 'Crime + Punishment in Suburbia', 'year': 2000}
# {'count': 2, 'title': 'Polycarp', 'year': 2015}
# {'count': 2, 'title': 'Run, Simon, Run', 'year': 1970}
# {'count': 2, 'title': 'Oye Lucky! Lucky Oye!', 'year': 2008}
# {'count': 2, 'title': 'Beautiful Girls', 'year': 1996}
# {'count': 2, 'title': 'Steam of Life', 'year': 2010}
# {'count': 2, 'title': 'The Painting', 'year': 2011}
# {'count': 2, 'title': 'Two Weeks Notice', 'year': 2002}
# {'count': 2, 'title': 'The Kite Runner', 'year': 2007}
# {'count': 2, 'title': 'Newsfront', 'year': 1978}
# {'count': 2, 'title': 'Igor', 'year': 2008}
# {'count': 2, 'title': 'Stop! Or My Mom Will Shoot', 'year': 1992}
# {'count': 2, 'title': 'Just Like a Woman', 'year': 2012}
# {'count': 2, 'title': 'Goodfellas', 'year': 1990}
# {'count': 2, 'title': 'Love Without Pity', 'year': 1989}
# {'count': 2, 'title': '40 Pounds of Trouble', 'year': 1962}
# {'count': 2, 'title': 'The Untouchables', 'year': 1987}
# {'count': 2, 'title': 'Shakthi: The Power', 'year': 2002}
# {'count': 2, 'title': 'The Salton Sea', 'year': 2002}
# {'count': 2, 'title': 'Yoru no onnatachi', 'year': 1948}
# {'count': 2, 'title': 'Zarafa', 'year': 2012}
# {'count': 2, 'title': 'No Turning Back', 'year': 2001}
# {'count': 2, 'title': 'The Mugger', 'year': 2007}
# {'count': 2, 'title': 'The Clockmaker of St. Paul', 'year': 1974}
# {'count': 2, 'title': 'The Imitation Game', 'year': 2014}
# {'count': 2, 'title': 'Hush!', 'year': 2001}
# {'count': 2, 'title': 'Larry Kramer in Love and Anger', 'year': 2015}
# {'count': 2, 'title': 'I Even Met Happy Gypsies', 'year': 1967}
# {'count': 2, 'title': 'Son of Rambow', 'year': 2007}
# {'count': 2, 'title': 'Radio', 'year': 2003}
# {'count': 2, 'title': 'The Theory of Everything', 'year': 2014}
# {'count': 2, 'title': 'Mondo', 'year': 1995}
# {'count': 2, 'title': 'Oktober November', 'year': 2013}
# {'count': 2, 'title': 'Sacrifice', 'year': 2010}
# {'count': 2, 'title': 'Bitva za Sevastopol', 'year': 2015}
# {'count': 2, 'title': 'My Life Without Me', 'year': 2003}
# {'count': 2, 'title': 'Bang the Drum Slowly', 'year': 1973}
# {'count': 2, 'title': 'April and the Extraordinary World', 'year': 2015}
# {'count': 2, 'title': 'Morgen', 'year': 2010}
# {'count': 2, 'title': 'The Moon in the Gutter', 'year': 1983}
# {'count': 2, 'title': 'Joanna', 'year': 2013}
# {'count': 2, 'title': 'In the Name of the Pope King', 'year': 1977}
# {'count': 2, 'title': 'Percy Jackson: Sea of Monsters', 'year': 2013}
# {'count': 2, 'title': 'Autohystoria', 'year': 2007}
# {'count': 2, 'title': 'Wife', 'year': 1953}
# {'count': 2, 'title': 'Drowsiness', 'year': 2008}
# {'count': 2, 'title': 'Bonjour Monsieur Shlomi', 'year': 2003}
# {'count': 2, 'title': 'THX 1138', 'year': 1971}
# {'count': 2, 'title': 'The Left Handed Gun', 'year': 1958}
# {'count': 2, 'title': "Varian's War", 'year': 2001}
# {'count': 2, 'title': 'Ju-on: The Grudge', 'year': 2002}
# {'count': 2, 'title': 'Thirteen', 'year': 2003}
# {'count': 2, 'title': 'Undertow', 'year': 2004}
# {'count': 2, 'title': 'Trial', 'year': 1955}
# {'count': 2, 'title': "The Butterfly's Dream", 'year': 2013}
# {'count': 2, 'title': 'City Heat', 'year': 1984}
# {'count': 2, 'title': 'Bestseller', 'year': 2010}
# {'count': 2, 'title': 'Precious', 'year': 2009}
# {'count': 2, 'title': 'Dustbin Baby', 'year': 2008}
# {'count': 2, 'title': 'Torque', 'year': 2004}
# {'count': 2, 'title': 'Mèbius', 'year': 2013}
# {'count': 2, 'title': 'The New Adventures of Pippi Longstocking', 'year': 1988}
# {'count': 2, 'title': 'The House on Carroll Street', 'year': 1988}
# {'count': 2, 'title': 'Raincoat', 'year': 2004}
# {'count': 2, 'title': 'Dark Horse', 'year': 2015}
# {'count': 2, 'title': 'Cheap Smokes', 'year': 2000}
# {'count': 2, 'title': 'Sword Art Online Extra Edition', 'year': 2013}
# {'count': 2, 'title': 'Annaluise & Anton', 'year': 1999}
# {'count': 2, 'title': 'The Infinite Man', 'year': 2014}
# {'count': 2, 'title': 'Three Colors: Blue', 'year': 1993}
# {'count': 2, 'title': 'Mother Dao, the Turtlelike', 'year': 1995}
# {'count': 2, 'title': 'The Falling', 'year': 2014}
# {'count': 2, 'title': 'La escopeta nacional', 'year': 1978}
# {'count': 2, 'title': 'Ghostbusters II', 'year': 1989}
# {'count': 2, 'title': 'Against All Odds', 'year': 1984}
# {'count': 2, 'title': 'Cattle Annie and Little Britches', 'year': 1981}
# {'count': 2, 'title': 'The Last of the High Kings', 'year': 1996}
# {'count': 2, 'title': 'A Brilliant Young Mind', 'year': 2014}
# {'count': 2, 'title': 'The Union', 'year': 2011}
# {'count': 2, 'title': 'Remember My Name', 'year': 1978}
# {'count': 2, 'title': 'Kisaragi', 'year': 2007}
# {'count': 2, 'title': 'A Little Help', 'year': 2010}
# {'count': 2, 'title': 'What About Bob?', 'year': 1991}
# {'count': 2, 'title': 'The Wild and Wonderful Whites of West Virginia', 'year': 2009}
# {'count': 2, 'title': 'The Raven', 'year': 2012}
# {'count': 2, 'title': 'Alfie', 'year': 1966}
# {'count': 2, 'title': 'Suspect X', 'year': 2008}
# {'count': 2, 'title': 'Kopps', 'year': 2003}
# {'count': 2, 'title': 'Somewhere', 'year': 2010}
# {'count': 2, 'title': 'The Prisoner', 'year': 1955}
# {'count': 2, 'title': 'Ronin', 'year': 1998}
# {'count': 2, 'title': 'Utomlyonnye solntsem 2: Predstoyanie', 'year': 2010}
# {'count': 2, 'title': 'The Wizards Return: Alex vs. Alex', 'year': 2013}
# {'count': 2, 'title': 'Talk Radio', 'year': 1988}
# {'count': 2, 'title': 'Sweet Evil', 'year': 2010}
# {'count': 2, 'title': 'The Lost Bladesman', 'year': 2011}
# {'count': 2, 'title': 'Ghulam', 'year': 1998}
# {'count': 2, 'title': 'Cubeè: Hypercube', 'year': 2002}
# {'count': 2, 'title': 'A City of Sadness', 'year': 1989}
# {'count': 2, 'title': 'Toad Road', 'year': 2012}
# {'count': 2, 'title': 'Daybreakers', 'year': 2009}
# {'count': 2, 'title': 'Yves Saint Laurent', 'year': 2014}
# {'count': 2, 'title': 'Beetle Queen Conquers Tokyo', 'year': 2009}
# {'count': 2, 'title': 'The End of Suburbia: Oil Depletion and the Collapse of the American Dream', 'year': 2004}
# {'count': 2, 'title': 'Latter Days', 'year': 2003}
# {'count': 2, 'title': 'The Tough Ones', 'year': 1999}
# {'count': 2, 'title': 'Black Day Blue Night', 'year': 1995}
# {'count': 2, 'title': 'Muzi bez krèdel', 'year': 1946}
# {'count': 2, 'title': "Avellaneda's Moon", 'year': 2004}
# {'count': 2, 'title': 'Not Suitable for Children', 'year': 2012}
# {'count': 2, 'title': 'A House Built on Water', 'year': 2003}
# {'count': 2, 'title': 'Princess Mononoke', 'year': 1997}
# {'count': 2, 'title': 'Himizu', 'year': 2011}
# {'count': 2, 'title': '600 Millas', 'year': 2015}
# {'count': 2, 'title': 'The Siege', 'year': 1998}
# {'count': 2, 'title': 'Om Shanti Om', 'year': 2007}
# {'count': 2, 'title': 'Mann tut was Mann kann', 'year': 2012}
# {'count': 2, 'title': 'Archangel', 'year': 1990}
# {'count': 2, 'title': 'Dreamcatcher', 'year': 2015}
# {'count': 2, 'title': 'Wild Flowers', 'year': 2000}
# {'count': 2, 'title': 'Dance, Girl, Dance', 'year': 1940}
# {'count': 2, 'title': 'Saint Jack', 'year': 1979}
# {'count': 2, 'title': 'In the Grayscale', 'year': 2015}
# {'count': 2, 'title': 'Yankee Doodle Dandy', 'year': 1942}
# {'count': 2, 'title': 'Delbaran', 'year': 2001}
# {'count': 2, 'title': 'The Big Lebowski', 'year': 1998}
# {'count': 2, 'title': "Forever's End", 'year': 2013}
# {'count': 2, 'title': "The Devil's Backbone", 'year': 2001}
# {'count': 2, 'title': 'A League of Their Own', 'year': 1992}
# {'count': 2, 'title': 'Source Code', 'year': 2011}
# {'count': 2, 'title': 'Big Game', 'year': 2014}
# {'count': 2, 'title': 'The Greggs', 'year': 2014}
# {'count': 2, 'title': 'Like the Wind', 'year': 2013}
# {'count': 2, 'title': 'Boogie', 'year': 2009}
# {'count': 2, 'title': 'Red Riding Hood', 'year': 2011}
# {'count': 2, 'title': 'Nine Months', 'year': 1995}
# {'count': 2, 'title': 'The Floating Castle', 'year': 2012}
# {'count': 2, 'title': 'Day & Night', 'year': 2010}
# {'count': 2, 'title': 'Johnny Handsome', 'year': 1989}
# {'count': 2, 'title': 'Slap Shot', 'year': 1977}
# {'count': 2, 'title': 'Unbreakable', 'year': 2000}
# {'count': 2, 'title': 'Secret Smile', 'year': 2005}
# {'count': 2, 'title': 'Elliot Loves', 'year': 2012}
# {'count': 2, 'title': 'Starter for 10', 'year': 2006}
# {'count': 2, 'title': 'Class Action', 'year': 1991}
# {'count': 2, 'title': 'Rich Kids', 'year': 1979}
# {'count': 2, 'title': 'The Boxcar Children', 'year': 2014}
# {'count': 2, 'title': 'Ride Along', 'year': 2014}
# {'count': 2, 'title': 'The Longest Week', 'year': 2014}
# {'count': 2, 'title': 'De vlaschaard', 'year': 1985}
# {'count': 2, 'title': 'Vitus', 'year': 2006}
# {'count': 2, 'title': 'Joe Hill', 'year': 1971}
# {'count': 2, 'title': 'Godzilla 1985', 'year': 1984}
# {'count': 2, 'title': 'The Clan - Tale of the Frogs', 'year': 1984}
# {'count': 2, 'title': 'White Lion', 'year': 2010}
# {'count': 2, 'title': 'Raavan', 'year': 2010}
# {'count': 2, 'title': 'The River', 'year': 1984}
# {'count': 2, 'title': 'Bionicle 2: Legends of Metru Nui', 'year': 2004}
# {'count': 2, 'title': 'Mister Johnson', 'year': 1990}
# {'count': 2, 'title': 'Min sèsters bèrn i Afrika', 'year': 2013}
# {'count': 2, 'title': 'The Last Sentence', 'year': 2012}
# {'count': 2, 'title': 'Joseph and the Amazing Technicolor Dreamcoat', 'year': 1999}
# {'count': 2, 'title': 'The Homesman', 'year': 2014}
# {'count': 2, 'title': 'Shock Head Soul', 'year': 2011}
# {'count': 2, 'title': 'The Policeman', 'year': 1971}
# {'count': 2, 'title': 'Heaven', 'year': 1998}
# {'count': 2, 'title': 'Addictions and Subtractions', 'year': 2004}
# {'count': 2, 'title': 'Just Eat It: A Food Waste Story', 'year': 2014}
# {'count': 2, 'title': 'How to Meet Girls from a Distance', 'year': 2012}
# {'count': 2, 'title': 'Swimming with Sharks', 'year': 1994}
# {'count': 2, 'title': 'Keep Your Distance', 'year': 2005}
# {'count': 2, 'title': "Fanie Fourie's Lobola", 'year': 2013}
# {'count': 2, 'title': 'Khottabych', 'year': 2006}
# {'count': 2, 'title': 'Monica Z', 'year': 2013}
# {'count': 2, 'title': 'Kristin Lavransdatter', 'year': 1995}
# {'count': 2, 'title': 'My Entire Life', 'year': 1996}
# {'count': 2, 'title': 'Our Beloved Month of August', 'year': 2008}
# {'count': 2, 'title': 'Lola', 'year': 1981}
# {'count': 2, 'title': 'Fiorile', 'year': 1993}
# {'count': 2, 'title': 'The Runway', 'year': 2010}
# {'count': 2, 'title': 'An American Girl Adventure', 'year': 2005}
# {'count': 2, 'title': 'Little Soldier', 'year': 2008}
# {'count': 2, 'title': "We Don't Live Here Anymore", 'year': 2004}
# {'count': 2, 'title': 'The Journey', 'year': 2014}
# {'count': 2, 'title': 'The Delta Force', 'year': 1986}
# {'count': 2, 'title': 'The Witches of Eastwick', 'year': 1987}
# {'count': 2, 'title': 'Testament', 'year': 1983}
# {'count': 2, 'title': 'Night Owls', 'year': 2015}
# {'count': 2, 'title': 'Tamala 2010: A Punk Cat in Space', 'year': 2002}
# {'count': 2, 'title': "By Dawn's Early Light", 'year': 2000}
# {'count': 2, 'title': 'Our Town', 'year': 2007}
# {'count': 2, 'title': 'Auk Nr. 8', 'year': 2010}
# {'count': 2, 'title': 'Lad: A Yorkshire Story', 'year': 2013}
# {'count': 2, 'title': 'Due Date', 'year': 2010}
# {'count': 2, 'title': 'Como agua para chocolate', 'year': 1992}
# {'count': 2, 'title': 'Jeanne la Pucelle II - Les prisons', 'year': 1994}
# {'count': 2, 'title': 'Oxygen', 'year': 1999}
# {'count': 2, 'title': 'Furry Vengeance', 'year': 2010}
# {'count': 2, 'title': 'Thorne: Sleepyhead', 'year': 2010}
# {'count': 2, 'title': 'Jungle', 'year': 2000}
# {'count': 2, 'title': 'Adult World', 'year': 2013}
# {'count': 2, 'title': 'Cannonball Fever', 'year': 1989}
# {'count': 2, 'title': 'Wings of Hope', 'year': 2000}
# {'count': 2, 'title': 'Zindagi Na Milegi Dobara', 'year': 2011}
# {'count': 2, 'title': 'Short Circuit 2', 'year': 1988}
# {'count': 2, 'title': 'The Angry Silence', 'year': 1960}
# {'count': 2, 'title': 'Crows Zero', 'year': 2007}
# {'count': 2, 'title': 'Enough', 'year': 2002}
# {'count': 2, 'title': '009 Re: Cyborg', 'year': 2012}
# {'count': 2, 'title': 'Prison Terminal: The Last Days of Private Jack Hall', 'year': 2013}
# {'count': 2, 'title': 'Oklahoma Crude', 'year': 1973}
# {'count': 2, 'title': 'Tear This Heart Out', 'year': 2008}
# {'count': 2, 'title': 'Miss Minoes', 'year': 2001}
# {'count': 2, 'title': 'Hammer & Tickle', 'year': 2006}
# {'count': 2, 'title': 'Black Mask', 'year': 1996}
# {'count': 2, 'title': 'Dèjè Vu', 'year': 1997}
# {'count': 2, 'title': 'Visitor Q', 'year': 2001}
# {'count': 2, 'title': 'Road, Movie', 'year': 2009}
# {'count': 2, 'title': 'Passion of Love', 'year': 1981}
# {'count': 2, 'title': 'Tizoc', 'year': 1957}
# {'count': 2, 'title': 'The Corruptor', 'year': 1999}
# {'count': 2, 'title': 'The Land Before Time XIII: The Wisdom of Friends', 'year': 2007}
# {'count': 2, 'title': 'Ghosts of the Abyss', 'year': 2003}
# {'count': 2, 'title': 'Recoil', 'year': 2011}
# {'count': 2, 'title': 'Phobia 2', 'year': 2009}
# {'count': 2, 'title': 'Mujhse Dosti Karoge!', 'year': 2002}
# {'count': 2, 'title': 'My Sweet Pepper Land', 'year': 2013}
# {'count': 2, 'title': 'Juno', 'year': 2007}
# {'count': 2, 'title': 'Pride', 'year': 2014}
# {'count': 2, 'title': 'Im Sommer wohnt er unten', 'year': 2015}
# {'count': 2, 'title': 'Robot Jox', 'year': 1989}
# {'count': 2, 'title': 'Madeline', 'year': 1998}
# {'count': 2, 'title': 'Warriors of Virtue', 'year': 1997}
# {'count': 2, 'title': 'Cop Dog', 'year': 2008}
# {'count': 2, 'title': 'Carriers', 'year': 2009}
# {'count': 2, 'title': 'Rated X', 'year': 2000}
# {'count': 2, 'title': "Charlotte's Web", 'year': 2006}
# {'count': 2, 'title': 'Common Threads: Stories from the Quilt', 'year': 1989}
# {'count': 2, 'title': 'Jack Frost', 'year': 1998}
# {'count': 2, 'title': 'Shiloh', 'year': 1996}
# {'count': 2, 'title': 'Mentor', 'year': 2006}
# {'count': 2, 'title': "What Doesn't Kill You", 'year': 2008}
# {'count': 2, 'title': 'The Unfaithful Wife', 'year': 1969}
# {'count': 2, 'title': 'The Cruise', 'year': 1998}
# {'count': 2, 'title': 'Breathing Room', 'year': 1996}
# {'count': 2, 'title': 'The Book of Life', 'year': 2014}
# {'count': 2, 'title': 'Mississippi Masala', 'year': 1991}
# {'count': 2, 'title': 'Anacondas: The Hunt for the Blood Orchid', 'year': 2004}
# {'count': 2, 'title': 'Familiar Grounds', 'year': 2011}
# {'count': 2, 'title': 'Striptease', 'year': 1996}
# {'count': 2, 'title': 'Gold', 'year': 1974}
# {'count': 2, 'title': 'Hacking Democracy', 'year': 2006}
# {'count': 2, 'title': 'Don', 'year': 1978}
# {'count': 2, 'title': 'The Nude Bomb', 'year': 1980}
# {'count': 2, 'title': 'Tremors 3: Back to Perfection', 'year': 2001}
# {'count': 2, 'title': 'The Assassination Bureau', 'year': 1969}
# {'count': 2, 'title': "We Don't Care About Music Anyway", 'year': 2009}
# {'count': 2, 'title': "Mary Shelley's Frankenstein", 'year': 1994}
# {'count': 2, 'title': 'Great Balls of Fire!', 'year': 1989}
# {'count': 2, 'title': 'Galaxy Express 999', 'year': 1979}
# {'count': 2, 'title': 'The Intouchables', 'year': 2011}
# {'count': 2, 'title': 'Cop & è', 'year': 1993}
# {'count': 2, 'title': 'Funeral March', 'year': 2001}
# {'count': 2, 'title': 'La dèsenchantèe', 'year': 1990}
# {'count': 2, 'title': 'Azzurro', 'year': 2000}
# {'count': 2, 'title': 'Lars and the Real Girl', 'year': 2007}
# {'count': 2, 'title': 'Destino', 'year': 2003}
# {'count': 2, 'title': 'Faithless', 'year': 2000}
# {'count': 2, 'title': 'Corporate', 'year': 2006}
# {'count': 2, 'title': 'The Magnificent Yankee', 'year': 1950}
# {'count': 2, 'title': '4 Minutes', 'year': 2006}
# {'count': 2, 'title': 'Bes Sehir', 'year': 2010}
# {'count': 2, 'title': 'Reversal of Fortune', 'year': 1990}
# {'count': 2, 'title': "The Band's Visit", 'year': 2007}
# {'count': 2, 'title': 'The Brotherhood', 'year': 1968}
# {'count': 2, 'title': 'C.H.U.D.', 'year': 1984}
# {'count': 2, 'title': 'Nocturna', 'year': 2007}
# {'count': 2, 'title': 'Pyaar Tune Kya Kiya...', 'year': 2001}
# {'count': 2, 'title': 'Ab Tak Chhappan', 'year': 2004}
# {'count': 2, 'title': 'OT: Our Town', 'year': 2002}
# {'count': 2, 'title': '10 Minutes', 'year': 2013}
# {'count': 2, 'title': 'National Velvet', 'year': 1944}
# {'count': 2, 'title': 'Frenzy', 'year': 1972}
# {'count': 2, 'title': "A Knight's Tale", 'year': 2001}
# {'count': 2, 'title': 'Pocahontas II: Journey to a New World', 'year': 1998}
# {'count': 2, 'title': 'Soft Shell Man', 'year': 2001}
# {'count': 2, 'title': 'Twilight Time', 'year': 1982}
# {'count': 2, 'title': 'The Unknown Soldier', 'year': 2006}
# {'count': 2, 'title': 'Pathfinder', 'year': 2007}
# {'count': 2, 'title': 'WarGames: The Dead Code', 'year': 2008}
# {'count': 2, 'title': 'Lady in the Water', 'year': 2006}
# {'count': 2, 'title': 'An Englishman in New York', 'year': 2009}
# {'count': 2, 'title': 'Wife! Be Like a Rose!', 'year': 1935}
# {'count': 2, 'title': 'The Bridesmaid', 'year': 2004}
# {'count': 2, 'title': 'Khaleja', 'year': 2010}
# {'count': 2, 'title': 'Wandering Sagittarius', 'year': 1993}
# {'count': 2, 'title': 'Volcano', 'year': 2011}
# {'count': 2, 'title': 'Chaos', 'year': 2001}
# {'count': 2, 'title': '9/11', 'year': 2002}
# {'count': 2, 'title': 'Corpse Bride', 'year': 2005}
# {'count': 2, 'title': 'Mr. Baseball', 'year': 1992}
# {'count': 2, 'title': 'The Future Is Woman', 'year': 1984}
# {'count': 2, 'title': 'Sand Castles', 'year': 2014}
# {'count': 2, 'title': 'Rouge', 'year': 1987}
# {'count': 2, 'title': 'Come Undone', 'year': 2000}
# {'count': 2, 'title': 'My Sweet Little Village', 'year': 1985}
# {'count': 2, 'title': 'Running Scared', 'year': 2006}
# {'count': 2, 'title': 'Jeepers Creepers', 'year': 2001}
# {'count': 2, 'title': 'West', 'year': 2013}
# {'count': 2, 'title': 'Helter Skelter', 'year': 2012}
# {'count': 2, 'title': "You Can't Take It With You", 'year': 1938}
# {'count': 2, 'title': 'S#x Acts', 'year': 2012}
# {'count': 2, 'title': 'Mother and Child', 'year': 2009}
# {'count': 2, 'title': 'Deadly Voyage', 'year': 1996}
# {'count': 2, 'title': 'What Happened Was...', 'year': 1994}
# {'count': 2, 'title': 'The Age of the Earth', 'year': 1980}
# {'count': 2, 'title': 'Dancemaker', 'year': 1998}
# {'count': 2, 'title': 'Between the Lines', 'year': 1977}
# {'count': 2, 'title': 'Martha', 'year': 1974}
# {'count': 2, 'title': 'Hatchet II', 'year': 2010}
# {'count': 2, 'title': "Everybody's Got Somebody... Not Me", 'year': 2012}
# {'count': 2, 'title': 'Lèon: The Professional', 'year': 1994}
# {'count': 2, 'title': 'Melissa P.', 'year': 2005}
# {'count': 2, 'title': 'Hitman Hart: Wrestling with Shadows', 'year': 1998}
# {'count': 2, 'title': 'Brigham City', 'year': 2001}
# {'count': 2, 'title': 'Little Children', 'year': 2006}
# {'count': 2, 'title': 'The Deluge', 'year': 1974}
# {'count': 2, 'title': 'Barbie in a Mermaid Tale', 'year': 2010}
# {'count': 2, 'title': 'Family Secrets', 'year': 2001}
# {'count': 2, 'title': 'Transistor Love Story', 'year': 2001}
# {'count': 2, 'title': 'The Velveteen Rabbit', 'year': 2009}
# {'count': 2, 'title': 'Ya ostayus', 'year': 2007}
# {'count': 2, 'title': "I'm the One You Want", 'year': 2014}
# {'count': 2, 'title': 'The Adultress', 'year': 1953}
# {'count': 2, 'title': 'The Elusive Corporal', 'year': 1962}
# {'count': 2, 'title': 'The 6th Day', 'year': 2000}
# {'count': 2, 'title': 'The Earth Is a Sinful Song', 'year': 1973}
# {'count': 2, 'title': 'Decency', 'year': 2013}
# {'count': 2, 'title': 'Heaven and Earth', 'year': 1990}
# {'count': 2, 'title': 'Marine Battleground', 'year': 1963}
# {'count': 2, 'title': 'Terminator Genisys', 'year': 2015}
# ...
# {'count': 1, 'title': "Don't Click", 'year': 2012}
# {'count': 1, 'title': 'The Longest Daycare', 'year': 2012}
# {'count': 1, 'title': 'Manson, My Name Is Evil', 'year': 2009}
# {'count': 1, 'title': 'Bitter Dream', 'year': 2004}
# {'count': 1, 'title': 'The Purge: Anarchy', 'year': 2014}
# {'count': 1, 'title': 'Dead & Breakfast', 'year': 2004}
# {'count': 1, 'title': 'Changeling', 'year': 2008}
# {'count': 1, 'title': 'Secret Society', 'year': 2000}
# {'count': 1, 'title': 'An American Terror', 'year': 2014}
# {'count': 1, 'title': 'Madagascar', 'year': 2011}
# {'count': 1, 'title': 'Pushing Tin', 'year': 1999}
# {'count': 1, 'title': 'The House Where Evil Dwells', 'year': 1982}
# {'count': 1, 'title': 'The Pajama Game', 'year': 1957}
# {'count': 1, 'title': "Madagascar 3: Europe's Most Wanted", 'year': 2012}
# {'count': 1, 'title': 'The 33', 'year': 2015}
# {'count': 1, 'title': 'The Sky Crawlers', 'year': 2008}
# {'count': 1, 'title': 'Die Nibelungen, Teil 1 - Siegfried', 'year': 1966}
# {'count': 1, 'title': 'The Nativity Story', 'year': 2006}
# {'count': 1, 'title': 'Out of Time', 'year': 2003}
# {'count': 1, 'title': 'Blind Mountain', 'year': 2007}
# {'count': 1, 'title': 'Station West', 'year': 1948}
# {'count': 1, 'title': 'The Accidental Tourist', 'year': 1988}
# {'count': 1, 'title': 'Hand Gun', 'year': 1994}
# {'count': 1, 'title': 'Shirin', 'year': 2008}
# {'count': 1, 'title': 'Lemon Tree', 'year': 2008}
# {'count': 1, 'title': 'Mother Kèsters Goes to Heaven', 'year': 1975}
# {'count': 1, 'title': 'Northfork', 'year': 2003}
# {'count': 1, 'title': 'Sombre', 'year': 1998}
# {'count': 1, 'title': 'Let Me In', 'year': 2010}
# {'count': 1, 'title': 'Between the Folds', 'year': 2008}
# {'count': 1, 'title': 'Bummer', 'year': 2003}
# {'count': 1, 'title': 'The Imaginarium of Doctor Parnassus', 'year': 2009}
# {'count': 1, 'title': 'The Deep Blue Sea', 'year': 2011}
# {'count': 1, 'title': 'In Good Company', 'year': 2004}
# {'count': 1, 'title': 'Bringing Out the Dead', 'year': 1999}
# {'count': 1, 'title': 'Koti-ikèvè', 'year': 2005}
# {'count': 1, 'title': 'Animal House', 'year': 1978}
# {'count': 1, 'title': 'Pinocchio', 'year': 1940}
# {'count': 1, 'title': 'Suburbia', 'year': 1983}
# {'count': 1, 'title': 'Alexander Graham Bell: The Sound and the Silence', 'year': 1992}
# {'count': 1, 'title': 'Istoriya Asi Klyachinoy, kotoraya lyubila, da ne vyshla zamuzh', 'year': 1966}
# {'count': 1, 'title': 'Lyubov-Morkov', 'year': 2007}
# {'count': 1, 'title': 'Pride and Glory', 'year': 2008}
# {'count': 1, 'title': 'Elizabethtown', 'year': 2005}
# {'count': 1, 'title': "A Woman's Tale", 'year': 1991}
# {'count': 1, 'title': 'Memphis Belle', 'year': 1990}
# {'count': 1, 'title': 'Permanent Midnight', 'year': 1998}
# {'count': 1, 'title': 'Confessions of a Nazi Spy', 'year': 1939}
# {'count': 1, 'title': 'Tuhlaajapoika', 'year': 1992}
# {'count': 1, 'title': 'Ring of Bright Water', 'year': 1969}
# {'count': 1, 'title': 'Death Note', 'year': '2006è2007'}
# {'count': 1, 'title': 'Death on the Staircase', 'year': 2004}
# {'count': 1, 'title': "Artie Shaw: Time Is All You've Got", 'year': 1985}
# {'count': 1, 'title': 'Love and Diane', 'year': 2002}
# {'count': 1, 'title': 'Under the Stars', 'year': 2007}
# {'count': 1, 'title': 'Hope Floats', 'year': 1998}
# {'count': 1, 'title': 'Les coquillettes', 'year': 2012}
# {'count': 1, 'title': 'Rènin-gai', 'year': 1990}
# {'count': 1, 'title': 'The Bride with White Hair', 'year': 1993}
# {'count': 1, 'title': 'Screamers', 'year': 1995}
# {'count': 1, 'title': 'The Ascent of Money', 'year': 2008}
# {'count': 1, 'title': 'Wait Until Spring, Bandini', 'year': 1989}
# {'count': 1, 'title': 'Dark City', 'year': 1998}
# {'count': 1, 'title': 'Body of Lies', 'year': 2008}
# {'count': 1, 'title': 'He Walked by Night', 'year': 1948}
# {'count': 1, 'title': "Midnight's Children", 'year': 2012}
# {'count': 1, 'title': 'Humraaz', 'year': 2002}
# {'count': 1, 'title': 'Camera Buff', 'year': 1979}
# {'count': 1, 'title': 'Chinese Odyssey 2002', 'year': 2002}
# {'count': 1, 'title': "A Midsummer Night's Dream", 'year': 1999}
# {'count': 1, 'title': 'Antique', 'year': 2008}
# {'count': 1, 'title': 'Radio tekee murron', 'year': 1951}
# {'count': 1, 'title': 'The Suspect', 'year': 2013}
# {'count': 1, 'title': 'Bloody Tie', 'year': 2006}
# {'count': 1, 'title': 'Conspiracy of Silence', 'year': 1991}
# {'count': 1, 'title': 'Jump In!', 'year': 2007}
# {'count': 1, 'title': 'The Desperate Hours', 'year': 1955}
# {'count': 1, 'title': 'Those Who Feel the Fire Burning', 'year': 2014}
# {'count': 1, 'title': 'Battleship', 'year': 2012}
# {'count': 1, 'title': 'Star Trek III: The Search for Spock', 'year': 1984}
# {'count': 1, 'title': 'Mumford', 'year': 1999}
# {'count': 1, 'title': 'Dr. Jekyll and Mr. Hyde', 'year': 1931}
# {'count': 1, 'title': 'Turbulence', 'year': 1997}
# {'count': 1, 'title': 'Love Field', 'year': 1992}
# {'count': 1, 'title': 'Three Times', 'year': 2005}
# {'count': 1, 'title': 'Hyde Park on Hudson', 'year': 2012}
# {'count': 1, 'title': 'Paycheck', 'year': 2003}
# {'count': 1, 'title': 'Jean Gentil', 'year': 2010}
# {'count': 1, 'title': 'Maids', 'year': 2001}
# {'count': 1, 'title': 'The Rickshaw Man', 'year': 1958}
# {'count': 1, 'title': 'Valmont', 'year': 1989}
# {'count': 1, 'title': 'Ghost Rider: Spirit of Vengeance', 'year': 2011}
# {'count': 1, 'title': 'Scooby-Doo', 'year': 2002}
# {'count': 1, 'title': "That's Entertainment! III", 'year': 1994}
# {'count': 1, 'title': 'Jo Jeeta Wohi Sikandar', 'year': 1992}
# {'count': 1, 'title': 'Chernobyl Diaries', 'year': 2012}
# {'count': 1, 'title': 'The Better Angels', 'year': 2014}
# {'count': 1, 'title': 'Housefull', 'year': 2010}
# {'count': 1, 'title': 'Tales from the Organ Trade', 'year': 2013}
# {'count': 1, 'title': 'Alice in Earnestland', 'year': 2015}
# {'count': 1, 'title': 'A Sinner in Mecca', 'year': 2015}
# {'count': 1, 'title': 'Rosenstrasse', 'year': 2003}
# {'count': 1, 'title': 'Christmas Every Day', 'year': 1996}
# {'count': 1, 'title': 'Panic', 'year': 2000}
# {'count': 1, 'title': 'Superman', 'year': 1978}
# {'count': 1, 'title': 'Chances Are', 'year': 1989}
# {'count': 1, 'title': 'Beach Party', 'year': 1963}
# {'count': 1, 'title': 'Game of Assassins', 'year': 2013}
# {'count': 1, 'title': 'Saving Grace', 'year': 2000}
# {'count': 1, 'title': 'The Toy', 'year': 1982}
# {'count': 1, 'title': 'Like Stars on Earth', 'year': 2007}
# {'count': 1, 'title': 'Do Fish Do It?', 'year': 2002}
# {'count': 1, 'title': 'Kiss of the Spider Woman', 'year': 1985}
# {'count': 1, 'title': 'The Protagonists', 'year': 1968}
# {'count': 1, 'title': 'Air Bud', 'year': 1997}
# {'count': 1, 'title': 'Going in Style', 'year': 1979}
# {'count': 1, 'title': 'Soap', 'year': 2006}
# {'count': 1, 'title': 'Parental Guidance', 'year': 2012}
# {'count': 1, 'title': 'Autumn Spring', 'year': 2001}
# {'count': 1, 'title': 'When Marnie Was There', 'year': 2014}
# {'count': 1, 'title': 'Frozen Land', 'year': 2005}
# {'count': 1, 'title': 'Happy Campers', 'year': 2001}
# {'count': 1, 'title': 'Find Love', 'year': 2006}
# {'count': 1, 'title': 'Algorithms', 'year': 2013}
# {'count': 1, 'title': 'Deadline', 'year': 2004}
# {'count': 1, 'title': 'Red Bells Part I: Mexico on Fire', 'year': 1982}
# {'count': 1, 'title': 'Green Tea', 'year': 2003}
# {'count': 1, 'title': 'Sylvia', 'year': 2003}
# {'count': 1, 'title': 'The Karamazov Brothers', 'year': 2008}
# {'count': 1, 'title': 'Picture Bride', 'year': 1994}
# {'count': 1, 'title': 'White Squall', 'year': 1996}
# {'count': 1, 'title': 'Serial Mom', 'year': 1994}
# {'count': 1, 'title': 'Zaytoun', 'year': 2012}
# {'count': 1, 'title': 'Rock On!!', 'year': 2008}
# {'count': 1, 'title': "Sharpe's Honour", 'year': 1994}
# {'count': 1, 'title': 'John Adams', 'year': 2008}
# {'count': 1, 'title': 'Unmade Beds', 'year': 1997}
# {'count': 1, 'title': 'Selma', 'year': 2014}
# {'count': 1, 'title': 'Not Love, Just Frenzy', 'year': 1996}
# {'count': 1, 'title': 'A Perfect Candidate', 'year': 1996}
# {'count': 1, 'title': 'Washington Square', 'year': 1997}
# {'count': 1, 'title': 'The Bang Bang Club', 'year': 2010}
# {'count': 1, 'title': 'Leave Her to Heaven', 'year': 1945}
# {'count': 1, 'title': 'Whatever It Takes', 'year': 2000}
# {'count': 1, 'title': 'Anna Karenina', 'year': 1935}
# {'count': 1, 'title': 'The Pelican Brief', 'year': 1993}
# {'count': 1, 'title': 'The Inheritance or Fuckoffguysgoodday', 'year': 1992}
# {'count': 1, 'title': 'Superbabies: Baby Geniuses 2', 'year': 2004}
# {'count': 1, 'title': 'An Amish Murder', 'year': 2013}
# {'count': 1, 'title': "A Man's Job", 'year': 2007}
# {'count': 1, 'title': 'The Discovery of Heaven', 'year': 2001}
# {'count': 1, 'title': 'Secrets of a Nurse', 'year': 1973}
# {'count': 1, 'title': "It's a Disaster", 'year': 2012}
# {'count': 1, 'title': 'The Heart Machine', 'year': 2014}
# {'count': 1, 'title': 'Pet Sematary', 'year': 1989}
# {'count': 1, 'title': 'Long Hello and Short Goodbye', 'year': 1999}
# {'count': 1, 'title': 'Predator 2', 'year': 1990}
# {'count': 1, 'title': 'Mune, le gardien de la lune', 'year': 2014}
# {'count': 1, 'title': 'Mille bolle blu', 'year': 1993}
# {'count': 1, 'title': 'Jonah Who Will Be 25 in the Year 2000', 'year': 1976}
# {'count': 1, 'title': 'Peeping Toms', 'year': 1973}
# {'count': 1, 'title': 'The Bear', 'year': 1988}
# {'count': 1, 'title': 'The Last Waltz', 'year': 1978}
# {'count': 1, 'title': 'Orchestra Rehearsal', 'year': 1978}
# {'count': 1, 'title': 'Games of Love and Chance', 'year': 2003}
# {'count': 1, 'title': 'The Mafu Cage', 'year': 1978}
# {'count': 1, 'title': 'Legally Blonde: The Musical', 'year': 2007}
# {'count': 1, 'title': 'Bleak Moments', 'year': 1971}
# {'count': 1, 'title': 'Scooby-Doo! Frankencreepy', 'year': 2014}
# {'count': 1, 'title': 'Silent Hill: Revelation 3D', 'year': 2012}
# {'count': 1, 'title': 'Love Steaks', 'year': 2013}
# {'count': 1, 'title': 'The New Land', 'year': 1972}
# {'count': 1, 'title': 'The Gathering', 'year': 2003}
# {'count': 1, 'title': 'A Kid for Two Farthings', 'year': 1955}
# {'count': 1, 'title': 'Cronicas', 'year': 2004}
# {'count': 1, 'title': 'Hitchcock', 'year': 2012}
# {'count': 1, 'title': 'The Substance of Fire', 'year': 1996}
# {'count': 1, 'title': 'Surprise!', 'year': 1995}
# {'count': 1, 'title': 'Because I Said So', 'year': 2007}
# {'count': 1, 'title': 'Bury My Heart at Wounded Knee', 'year': 2007}
# {'count': 1, 'title': 'Fear', 'year': 1996}
# {'count': 1, 'title': 'Move', 'year': 2012}
# {'count': 1, 'title': 'Mean Girls', 'year': 2004}
# {'count': 1, 'title': 'The Fisher King', 'year': 1991}
# {'count': 1, 'title': 'The Juche Idea', 'year': 2008}
# {'count': 1, 'title': 'Cargo', 'year': 2009}
# {'count': 1, 'title': 'Taal', 'year': 1999}
# {'count': 1, 'title': 'Real', 'year': 2013}
# {'count': 1, 'title': 'Vysotskiy. Spasibo, chto zhivoy', 'year': 2011}
# {'count': 1, 'title': 'Blink', 'year': 1994}
# {'count': 1, 'title': 'Man on the Train', 'year': 2002}
# {'count': 1, 'title': 'The Life and Times of Hank Greenberg', 'year': 1998}
# {'count': 1, 'title': 'Mighty Joe Young', 'year': 1998}
# {'count': 1, 'title': 'Survival Island', 'year': 2005}
# {'count': 1, 'title': 'Megaville', 'year': 1990}
# {'count': 1, 'title': 'Orgasm Inc.', 'year': 2009}
# {'count': 1, 'title': 'Chelsea Walls', 'year': 2001}
# {'count': 1, 'title': 'Love Scenes from Planet Earth', 'year': 1998}
# {'count': 1, 'title': 'Midnight Dancers', 'year': 1994}
# {'count': 1, 'title': 'Two Friends', 'year': 2015}
# {'count': 1, 'title': 'Who Am I?', 'year': 1998}
# {'count': 1, 'title': 'The Enemy Below', 'year': 1957}
# {'count': 1, 'title': 'Dust in the Wind', 'year': 1987}
# {'count': 1, 'title': 'A Christmas Carol', 'year': 1999}
# {'count': 1, 'title': 'Vic + Flo Saw a Bear', 'year': 2013}
# {'count': 1, 'title': 'Daikaijè kèchèsen: Gamera tai Gyaosu', 'year': 1967}
# {'count': 1, 'title': "There's No Business Like Show Business", 'year': 1954}
# {'count': 1, 'title': 'Coming to America', 'year': 1988}
# {'count': 1, 'title': 'The Master Plan', 'year': 2015}
# {'count': 1, 'title': 'Measuring the World', 'year': 2012}
# {'count': 1, 'title': 'Millennium Actress', 'year': 2001}
# {'count': 1, 'title': 'Nightwatch', 'year': 1997}
# {'count': 1, 'title': 'The Players Club', 'year': 1998}
# {'count': 1, 'title': 'Taking Sides', 'year': 2001}
# {'count': 1, 'title': 'Mystery Science Theater 3000: The Movie', 'year': 1996}
# {'count': 1, 'title': 'The Art of the Steal', 'year': 2013}
# {'count': 1, 'title': 'Medeas', 'year': 2013}
# {'count': 1, 'title': 'Breaking and Entering', 'year': 2006}
# {'count': 1, 'title': 'Stalled', 'year': 2013}
# {'count': 1, 'title': "At the Earth's Core", 'year': 1976}
# {'count': 1, 'title': 'Space Cowboys', 'year': 2000}
# {'count': 1, 'title': 'The Whisperer in Darkness', 'year': 2011}
# {'count': 1, 'title': 'Hardboiled Egg', 'year': 1997}
# {'count': 1, 'title': 'The Here After', 'year': 2015}
# {'count': 1, 'title': "Love Don't Cost a Thing", 'year': 2003}
# {'count': 1, 'title': 'Wonder Man', 'year': 1945}
# {'count': 1, 'title': 'Beauty Shop', 'year': 2005}
# {'count': 1, 'title': 'Les bessones del carrer de Ponent', 'year': 2010}
# {'count': 1, 'title': 'Open Range', 'year': 2003}
# {'count': 1, 'title': 'Wild Combination: A Portrait of Arthur Russell', 'year': 2008}
# {'count': 1, 'title': 'Battle for Terra', 'year': 2007}
# {'count': 1, 'title': 'The Bride', 'year': 1985}
# {'count': 1, 'title': '95ers: Echoes', 'year': 2013}
# {'count': 1, 'title': 'Knocked Up', 'year': 2007}
# {'count': 1, 'title': "The Librarian: Return to King Solomon's Mines", 'year': 2006}
# {'count': 1, 'title': 'Kenau', 'year': 2014}
# {'count': 1, 'title': 'Disco Pigs', 'year': 2001}
# {'count': 1, 'title': '12', 'year': 2007}
# {'count': 1, 'title': 'Unknown White Male', 'year': 2005}
# {'count': 1, 'title': 'SUBWAYStories: Tales from the Underground', 'year': 1997}
# {'count': 1, 'title': 'Captain Conan', 'year': 1996}
# {'count': 1, 'title': 'Argo', 'year': 2012}
# {'count': 1, 'title': 'For Your Eyes Only', 'year': 1981}
# {'count': 1, 'title': 'Os Canibais', 'year': 1988}
# {'count': 1, 'title': 'Letters from the Big Man', 'year': 2011}
# {'count': 1, 'title': 'Pièero', 'year': 2001}
# {'count': 1, 'title': '5ive Days to Midnight', 'year': 2004}
# {'count': 1, 'title': 'May 18', 'year': 2007}
# {'count': 1, 'title': "Blind Spot. Hitler's Secretary", 'year': 2002}
# {'count': 1, 'title': 'Who Are You, Polly Magoo?', 'year': 1966}
# {'count': 1, 'title': 'Cèmo pasan las horas', 'year': 2005}
# {'count': 1, 'title': 'The Promise', 'year': 2005}
# {'count': 1, 'title': 'Teenage Paparazzo', 'year': 2010}
# {'count': 1, 'title': 'Pingpong', 'year': 2006}
# {'count': 1, 'title': 'Groundhog Day', 'year': 1993}
# {'count': 1, 'title': 'Harold & Kumar Go to White Castle', 'year': 2004}
# {'count': 1, 'title': 'Drive', 'year': 1997}
# {'count': 1, 'title': 'Die, Mommie, Die!', 'year': 2003}
# {'count': 1, 'title': 'Omkara', 'year': 2006}
# {'count': 1, 'title': 'Elizabeth: The Golden Age', 'year': 2007}
# {'count': 1, 'title': 'Short Stories', 'year': 2012}
# {'count': 1, 'title': 'Korso', 'year': 2014}
# {'count': 1, 'title': "Women's Day", 'year': 2012}
# {'count': 1, 'title': 'Penumbra', 'year': 2013}
# {'count': 1, 'title': 'Will You Cross the Skies for Me?', 'year': 2010}
# {'count': 1, 'title': 'Fanny and Alexander', 'year': 1982}
# {'count': 1, 'title': 'Leaving Las Vegas', 'year': 1995}
# {'count': 1, 'title': 'The Dresser', 'year': 1983}
# {'count': 1, 'title': 'Anne of Avonlea', 'year': 1987}
# {'count': 1, 'title': 'The Ninth Configuration', 'year': 1980}
# {'count': 1, 'title': 'Hellsinki', 'year': 2009}
# {'count': 1, 'title': 'Bhaag Milkha Bhaag', 'year': 2013}
# {'count': 1, 'title': 'Still Crazy', 'year': 1998}
# {'count': 1, 'title': 'Scourge', 'year': 2008}
# {'count': 1, 'title': 'Flight of the Navigator', 'year': 1986}
# {'count': 1, 'title': 'Confessions of a Superhero', 'year': 2007}
# {'count': 1, 'title': 'El rostro', 'year': 2012}
# {'count': 1, 'title': 'The Wackness', 'year': 2008}
# {'count': 1, 'title': 'Teenage Caveman', 'year': 2002}
# {'count': 1, 'title': 'Rope', 'year': 1948}
# {'count': 1, 'title': "The Making of '...And God Spoke'", 'year': 1993}
# {'count': 1, 'title': 'Wolf', 'year': 1994}
# {'count': 1, 'title': 'Uitgesloten', 'year': 2001}
# {'count': 1, 'title': 'The Ape', 'year': 2009}
# {'count': 1, 'title': 'Hellraiser: Bloodline', 'year': 1996}

# %% [markdown]
# #### Задача 2.2 — **1 балл**

# %% [markdown]
# Используя данные, полученные в задаче 2.1, выведите на экран столбчатую диаграмму, показывающую топ-20 наиболее комментируемых фильмов. По оси ординат выведите названия этих фильмов (подписи разместите слева диаграммы), по оси абсцисс — количество комментариев.
#
# Для решения задачи можно использовать любую библиотеку, например Seaborn или Matplotlib.

# %%
import matplotlib.pyplot as plt

pipeline = [
    {"$group": {"_id": "$movie_id", "count": {"$sum": 1}}},
    {"$sort": {"count": -1}},
    {"$limit": 20},
    {"$lookup": {
        "from": "movies",
        "localField": "_id",
        "foreignField": "_id",
        "as": "movie_info"
    }},
    {"$unwind": "$movie_info"},
    {"$addFields": {
        "title": "$movie_info.title",
        "year": "$movie_info.year"
    }},
    {"$project": {"_id": 0, "title": 1, "count": 1}}
]

results = list(comments_collection.aggregate(pipeline))

titles = [movie["title"] for movie in results]
comment_counts = [movie["count"] for movie in results]

plt.figure(figsize=(10, 8))
plt.barh(titles[::-1], comment_counts[::-1])
plt.xlabel("Количество комментариев")
plt.ylabel("Название фильма")
plt.title("Топ-20 наиболее комментируемых фильмов")
plt.grid(axis="x", linestyle="--", alpha=0.7)

plt.show()
